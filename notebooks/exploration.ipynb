# %%
from herbie import Herbie
import xarray as xr

# %%
H = Herbie(
  '2023-01-01 12:00',
  model='hrrr',
  product='sfc',
  fxx=6
)
# Out:
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2023-Jan-01 12:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws

# %%
H.inventory()
# Out:
#      grib_message  start_byte     end_byte                range  \
# 0               1           0     541322.0             0-541322
# 1               2      541323     748425.0        541323-748425
# 2               3      748426    1471575.0       748426-1471575
# 3               4     1471576    1859941.0      1471576-1859941
# 4               5     1859942    3261694.0      1859942-3261694
# ..            ...         ...          ...                  ...
# 168           169   161481607  161497240.0  161481607-161497240
# 169           170   161497241  163035307.0  161497241-163035307
# 170           171   163035308  165353579.0  163035308-165353579
# 171           172   165353580  166762753.0  165353580-166762753
# 172           173   166762754          NaN           166762754-
#
#          reference_time          valid_time  \
# 0   2023-01-01 12:00:00 2023-01-01 18:00:00
# 1   2023-01-01 12:00:00 2023-01-01 18:00:00
# 2   2023-01-01 12:00:00 2023-01-01 18:00:00
# ...

# %%
H.download(save_dir="../data/raw/")
# Out:
# PosixPath('../data/raw/hrrr/20230101/hrrr.t12z.wrfsfcf06.grib2')

# %%
ds = xr.open_dataset(filename_or_obj="../data/raw/hrrr/20230101/hrrr.t12z.wrfsfcf06.grib2", engine="cfgrib", filter_by_keys={'typeOfLevel': 'Unknown'})

# %%
for v in ds:
    print("{}, {}, {}".format(v, ds[v].attrs["long_name"], ds[v].attrs["units"]))

# %% [markdown]
# # Now trying INMET Data

# %%
import pandas as pd

# %%
csv_file = "../data/raw/generatedBy_react-csv.csv"

# %%
columns = ["Data", "Hora (UTC)", "Temp. Ins. (C)", "Temp. Max. (C)", "Temp. Min. (C)",
           "Umi. Ins. (%)", "Umi. Max. (%)", "Umi. Min. (%)", "Pto Orvalho Ins. (C)",
           "Pto Orvalho Max. (C)", "Pto Orvalho Min. (C)", "Pressao Ins. (hPa)",
           "Pressao Max. (hPa)", "Pressao Min. (hPa)", "Vel. Vento (m/s)", "Dir. Vento (m/s)",
           "Raj. Vento (m/s)", "Radiacao (KJ/m²)", "Chuva (mm)"]

columns_to_select = ["Data", "Temp. Ins. (C)", "Temp. Max. (C)", "Temp. Min. (C)", "Chuva (mm)"]

# %%
path_brasilia = "../data/raw/Dados_INMET/dados_A001_D_2023-01-01_2023-12-31.csv"
path_goiania = "../data/raw/Dados_INMET/dados_A002_D_2023-01-01_2023-12-31.csv"
path_morrinhos = "../data/raw/Dados_INMET/dados_A003_D_2023-01-01_2023-12-31.csv"

# %%
cidades = {
    "ABROLHOS": "A422",
    "ACARAU": "A360",
    "AFONSO_CLAUDIO": "A657",
    "AGUA_BOA": "A908",
    "AGUA_CLARA": "A756",
    "AGUAS_EMENDADAS": "A045",
    "AGUAS_VERMELHAS": "A549",
    "AIMORES": "A534",
    "ALEGRE": "A617",
    "ALEGRETE": "A826",
    "ALFREDO_CHAVES": "A615",
    "ALMAS": "A053",
    "ALMENARA": "A508",
    "ALTA_FLORESTA": "A924",
    "ALTAMIRA": "A253",
    "ALTO_ARAGUAIA": "A909",
    "ALTO_PARAISO_DE_GOIAS": "A024",
    "ALTO_PARNAIBA": "A223",
    "ALTO_TAQUARI": "A934",
    "ALVORADA_DO_GURGUEIA": "A336",
    "AMAMBAI": "A750",
    "AMARGOSA": "A434",
    "ANGICAL_DO_PIAUI": "A377",
    "ANGRA_DOS_REIS": "A628",
    "APIACAS": "A910",
    "APODI": "A340",
    "APUI": "A113",
    "AQUIDAUANA": "A719",
    "ARACAJU": "A409",
    "ARACUAI": "A566",
    "ARAGARCAS": "A013",
    "ARAGUACU": "A054",
    "ARAGUAINA": "A021",
    "ARAGUATINS": "A044",
    "ARAPIRACA": "A353",
    "ARARANGUA": "A867",
    "ARAXA": "A505",
    "ARCO_VERDE": "A309",
    "AREIA": "A310",
    "ARIQUEMES": "A940",
    "ARIRANHA": "A736",
    "ARRAIAL_DO_CABO": "A606",
    "AUTAZES": "A120",
    "AVARE": "A725",
    "BACABAL": "A220",
    "BAGE": "A827",
    "BAIXA_GRANDE_DO_RIBEIRO": "A375",
    "BALSAS": "A204",
    "BAMBUI": "A565",
    "BARBACENA": "A502",
    "BARBALHA": "A315",
    "BARCELOS": "A128",
    "BARRA": "A429",
    "BARRA_BONITA": "A741",
    "BARRA_DO_CORDA": "A221",
    "BARRA_DO_TURVO": "A746",
    "BARREIRAS": "A402",
    "BARRETOS": "A748",
    "BARUERI": "A755",
    "BATAGUASSU": "A759",
    "BAURU": "A705",
    "BEBEDOURO": "A764",
    "BELEM": "A201",
    "BELMONTE": "A447",
    "BELO_HORIZONTE:_PAMPLHA)": "A521",
    "BELO_HORIZONTE___CERCADINHO": "F501",
    "BENTO_GONCALVES": "A840",
    "BERTIOGA": "A765",
    "BOA_VISTA": "A135",
    "BOCA_DO_ACRE": "A110",
    "BOM_JARDIM_DA_SERRA___MORRO_DA_IGREJA": "A845",
    "BOM_JESUS_DA_LAPA": "A418",
    "BOM_JESUS_DO_PIAUI": "A326",
    "BRAGANCA": "A226",
    "BRAGANCA_PAULISTA": "A744",
    "BRASILIA": "A001",
    "BRASNORTE:_NOVO_MUNDO": "A927",
    "BRAZLANDIA": "A042",
    "BREJO_GRANDE": "A421",
    "BREVES": "A228",
    "BRUMADO": "A433",
    "BURITICUPU": "A238",
    "BURITIRAMA": "A432",
    "BURITIS": "A544",
    "CABACEIRAS": "A348",
    "CABROBO": "A329",
    "CACADOR": "A859",
    "CACAPAVA_DO_SUL": "A812",
    "CACHOEIRA_PAULISTA": "A769",
    "CACOAL": "A939",
    "CAIAPONIA": "A023",
    "CAICO": "A316",
    "CALCANHAR": "A344",
    "CALDAS": "A530",
    "CAMAQUA": "A838",
    "CAMARATUBA": "A352",
    "CAMBARA_DO_SUL": "A897",
    "CAMBUCI": "A604",
    "CAMETA": "A236",
    "CAMPINA_DA_LAGOA": "B803",
    "CAMPINA_GRANDE": "A313",
    "CAMPINA_VERDE": "A519",
    "CAMPO_BOM": "A884",
    "CAMPO_GRANDE": "A702",
    "CAMPO_MAIOR": "A376",
    "CAMPO_NOVO_DOS_PARECIS": "A905",
    "CAMPO_VERDE": "A912",
    "CAMPOS_DO_JORDAO": "A706",
    "CAMPOS_DOS_GOYTACAZES": "A607",
    "CAMPOS_DOS_GOYTACAZES___SAO_TOME": "A620",
    "CAMPOS_LINDOS": "A043",
    "CAMPOS_NOVOS": "A898",
    "CAMPOS_SALES": "A347",
    "CANELA": "A879",
    "CANGUCU": "A811",
    "CANTO_DO_BURITI": "A365",
    "CAPAO_DO_LEAO:_PELOTAS": "A887",
    "CAPELINHA": "A541",
    "CAPITAO_POCO": "A248",
    "CARACOL": "A337",
    "CARATINGA": "A554",
    "CARAVELAS": "A405",
    "CARLINDA": "A926",
    "CARMO": "A629",
    "CAROLINA": "A205",
    "CARUARU": "A341",
    "CASA_BRANCA": "A738",
    "CASSILANDIA": "A742",
    "CASTANHAL": "A202",
    "CASTELO_DO_PIAUI": "A361",
    "CASTRO": "A819",
    "CATALAO": "A034",
    "CAXIAS": "A237",
    "CHAPADA_GAUCHA": "A548",
    "CHAPADAO_DO_SUL": "A730",
    "CHAPADINHA": "A206",
    "CHAPECO": "A895",
    "CIDADE_GAUCHA": "A869",
    "CLEVELANDIA": "A876",
    "COARI": "A117",
    "COLINAS": "A222",
    "COLINAS_DO_TOCANTINS": "A049",
    "COLOMBO": "B806",
    "COMODORO": "A913",
    "CONCEICAO_DAS_ALAGOAS": "A520",
    "CONCEICAO_DO_ARAGUAIA": "A241",
    "CONDE": "A431",
    "CORONEL_PACHECO": "A557",
    "CORRENTE": "A374",
    "CORRENTINA": "A416",
    "CORUMBA": "A724",
    "CORURIPE": "A355",
    "COSTA_RICA": "A760",
    "COTRIGUACU": "A919",
    "COXIM": "A720",
    "CRATEUS": "A342",
    "CRISTALINA": "A036",
    "CRISTALINA:_FAZENDA_SANTA_MONICA)": "A056",
    "CRUZ_ALTA": "A853",
    "CRUZ_DAS_ALMAS": "A406",
    "CRUZEIRO_DO_SUL": "A108",
    "CUIABA": "A901",
    "CURACA": "A448",
    "ERECHIM": "A828",
    "ESPINOSA": "A543",
    "ESTREITO": "A224",
    "EUCLIDES_DA_CUNHA": "A442",
    "FAROL_de_SANTANA": "A217",
    "FEIJO": "A138",
    "FEIRA_DE_SANTANA": "A413",
    "FLORESTA": "A351",
    "FLORESTAL": "A535",
    "FLORIANO": "A311",
    "FLORIANOPOLIS": "A806",
    "FORMIGA": "A524",
    "FORMOSA_DO_RIO_PRETO": "A452",
    "FORMOSO_DO_ARAGUAIA": "A039",
    "FORTALEZA": "A305",
    "FOZ_DO_IGUACU": "A846",
    "FRANCA": "A708",
    "FREDERICO_WESTPHALEN": "A854",
    "GAMA:_PONT_ALTA": "A046",
    "GARANHUNS": "A322",
    "GAUCHA_DO_NORTE": "A930",
    "GENERAL_CARNEIRO": "A875",
    "GILBUES": "A364",
    "GOIANESIA": "A022",
    "GOIANIA": "A002",
    "GOIAS": "A014",
    "GOIOERE": "A825",
    "GOVERNADOR_VALADARES": "A532",
    "GRAJAU": "A207",
    "GUANAMBI": "A426",
    "GUANHAES": "A533",
    "GUARAMIRANGA": "A314",
    "GUARANTA_DO_NORTE": "A906",
    "GUARDA_MOR": "A546",
    "GUIRATINGA": "A932",
    "GURUPI": "A019",
    "HUMAITA": "A112",
    "IBIMIRIM": "A349",
    "IBIRITE:_ROLAMOCA": "A555",
    "IBIRUBA": "A883",
    "IBITINGA": "A737",
    "IBOTIRAMA": "A439",
    "ICARAIMA": "A824",
    "IGUAPE": "A712",
    "IGUATU": "A319",
    "ILHEUS": "A410",
    "IMPERATRIZ": "A225",
    "INACIO_MARTINS": "A823",
    "INDAIAL": "A817",
    "IPANGUACU": "A372",
    "IPIAU": "A445",
    "IPORA": "A028",
    "IRECE": "A424",
    "ITABAIANA": "A451",
    "ITABAIANINHA": "A417",
    "ITABERABA": "A408",
    "ITACOATIARA": "A121",
    "ITAITUBA": "A231",
    "ITAJAI": "A868",
    "ITAMARAJU": "A455",
    "ITAOBIM": "A550",
    "ITAPACI": "A015",
    "ITAPETINGA": "A446",
    "ITAPEVA": "A714",
    "ITAPIPOCA": "A359",
    "ITAPIRA": "A739",
    "ITAPOA": "A851",
    "ITAPORANGA": "A373",
    "ITAQUIRAI": "A752",
    "ITAUBAL": "A251",
    "ITIQUIRA": "A933",
    "ITIRUCU": "A407",
    "ITUIUTABA": "A512",
    "ITUMBIARA": "A035",
    "ITUPORANGA": "A863",
    "ITUVERAVA": "A753",
    "IVAI": "A818",
    "IVINHEMA": "A709",
    "JACOBINA": "A440",
    "JAGUARAO": "A836",
    "JAGUARIBE": "A358",
    "JAGUARUANA": "A339",
    "JALES": "A733",
    "JANUARIA": "A559",
    "JAPIRA": "A871",
    "JARDIM": "A758",
    "JATAI": "A016",
    "JEREMOABO": "A450",
    "JOACABA": "A841",
    "JOAO_PESSOA": "A320",
    "JOAO_PINHEIRO": "A553",
    "JOAQUIM_TAVORA": "A821",
    "JOSE_BONIFACIO": "A735",
    "JUARA": "A914",
    "JUINA": "A920",
    "JOAO_PINHEIRO": "A553",
    "JUTI": "A749",
    "LABREA": "A111",
    "LAGES": "A865",
    "LAGOA_DA_CONFUSAO": "A055",
    "LAGOA_VERMELHA": "A844",
    "LARANJEIRAS_DO_SUL": "B804",
    "LENÇÓIS": "A425",
    "LINHARES": "A614",
    "LINS": "A727",
    "LUIZ_EDUARDO_MAGALHAES": "A404",
    "LUZIANIA": "A012",
    "LAGUNA___FAROL_DE_SANTA_MARTA": "A866",
    "MACAE": "A608",
    "MACAJUBA": "A412",
    "MACAPA": "A249",
    "MACAU": "A317",
    "MACEIO": "A303",
    "MACHADO": "A567",
    "MAJOR_VIEIRA": "A864",
    "MAL._CANDIDO_RONDON": "A820",
    "MANACAPURU": "A119",
    "MANAUS": "A101",
    "MANHUACU": "A556",
    "MANICORE": "A133",
    "MANTENA": "A540",
    "MARABA": "A240",
    "MARACAJU": "A731",
    "MARAU": "A438",
    "MARECHAL_THAUMATURGO": "A137",
    "MARIA_DA_FE": "A531",
    "MARIANOPOLIS_DO_TO": "A041",
    "MARILANDIA": "A632",
    "MARILIA": "A763",
    "MARINGA": "A835",
    "MATEIROS": "A040",
    "MAUES": "A122",
    "MEDICILANDIA": "A209",
    "MINA_DO_PALITO": "A246",
    "MINEIROS": "A026",
    "MIRANDA": "A722",
    "MOCAMBINHO": "A539",
    "MONTALVANIA": "A526",
    "MONTE_ALEGRE": "A239",
    "MONTE_ALEGRE_DE_GOIAS": "A032",
    "MONTE_VERDE": "A509",
    "MONTEIRO": "A334",
    "MONTES_CLAROS": "A506",
    "MORADA_NOVA": "A332",
    "MORRETES": "A873",
    "MORRINHOS": "A003",
    "MOSSORO": "A318",
    "MOSTARDAS": "A878",
    "MURIAE": "A517",
    "NATAL": "A304",
    "NHUMIRIM": "A717",
    "NITEROI": "A627",
    "NOSSA_SENHORA_DA_GLORIA": "A453",
    "NOVA_FATIMA": "A842",
    "NOVA_FRIBURGO___SALINAS": "A624",
    "NOVA_MARINGA": "A928",
    "NOVA_PORTEIRINHA:_JANABA": "A563",
    "NOVA_TEBAS": "A822",
    "NOVA_UBIRATA": "A929",
    "NOVO_ARIPUANA": "A144",
    "NOVO_HORIZONTE": "A816",
    "NOVO_REPARTIMENTO": "A235",
    "OBIDOS": "A232",
    "OEIRAS": "A354",
    "OIAPOQUE": "A242",
    "OLIVEIRA": "A570",
    "OURICURI": "A366",
    "OURINHOS": "A716",
    "OURO_BRANCO": "A513",
    "PACAJA": "A210",
    "PALMARES": "A357",
    "PALMAS": "A009",
    "PALMEIRA_DAS_MISSOES": "A856",
    "PALMEIRA_DOS_INDIOS": "A327",
    "PAO_DE_ACUCAR": "A323",
    "PARACATU": "A571",
    "PARAGOMINAS": "A212",
    "PARANA": "A010",
    "PARANAIBA": "A710",
    "PARANAPOEMA": "A850",
    "PARANATINGA": "A915",
    "PARANOA:_COOPDF": "A047",
    "PARATY": "A619",
    "PARAUNA": "A027",
    "PARINTINS": "A123",
    "PARNAIBA": "A308",
    "PARQUE_ESTADUAL_CHANDLESS": "A102",
    "PASSA_QUATRO": "A529",
    "PASSO_FUNDO": "A839",
    "PASSOS": "A516",
    "PATOS": "A321",
    "PATOS_DE_MINAS": "A562",
    "PATROCINIO": "A523",
    "PAULISTANA": "A330",
    "PEDRO_AFONSO": "A020",
    "PEIXE": "A018",
    "PETROLINA": "A307",
    "PIATA": "A430",
    "PICO_DO_COUTO": "A610",
    "PICOS": "A343",
    "PIRACICABA": "A726",
    "PIRANHAS": "A371",
    "PIRAPORA": "A545",
    "PIRES_DO_RIO": "A033",
    "PIRIPIRI": "A335",
    "PIUM": "A051",
    "PLACAS": "A211",
    "PLANALTO": "A855",
    "POCO_VERDE": "A419",
    "POMPEU": "A560",
    "PONTA_PORA": "A703",
    "PONTES_E_LACERDA": "A937",
    "PORANGATU": "A005",
    "PORTO_ALEGRE___JARDIM_BOTANICO": "A801",
    "PORTO_ALEGRE__BELEM_NOVO": "B807",
    "PORTO_DE_MOZ": "A245",
    "PORTO_ESTRELA": "A935",
    "PORTO_GRANDE": "A244",
    "PORTO_MURTINHO": "A723",
    "PORTO_SEGURO": "A427",
    "PORTO_VELHO": "A925",
    "PORTO_WALTER": "A136",
    "POSSE": "A017",
    "PRADOPOLIS": "A747",
    "PREGUICAS": "A218",
    "PRESIDENTE_FIGUEIREDO": "A126",
    "PRESIDENTE_KENNEDY": "A622",
    "PRESIDENTE_PRUDENTE": "A707",
    "PRIMAVERA_DO_LESTE": "A923",
    "Paty_do_Alferes___Avelar": "A637",
    "QUARAI": "A831",
    "QUEIMADAS": "A436",
    "QUERENCIA": "A916",
    "QUIXADA": "A369",
    "QUIXERAMOBIM": "A325",
    "RANCHARIA": "A718",
    "RANCHO_QUEIMADO": "A870",
    "RECIFE": "A301",
    "REDENCAO": "A254",
    "REGISTRO": "A766",
    "REMANSO": "A423",
    "RESENDE": "A609",
    "RIBEIRA_DO_AMPARO": "A458",
    "RIO_BRANCO": "A104",
    "RIO_BRILHANTE": "A743",
    "RIO_CLARO": "A626",
    "RIO_DE_JANEIRO___FORTE_DE_COPACABANA": "A652",
    "RIO_DE_JANEIRO___JACAREPAGUA": "A636",
    "RIO_DE_JANEIRO___VILA_MILITAR": "A621",
    "RIO_DE_JANEIRO_MARAMBAIA": "A602",
    "RIO_DO_CAMPO": "A861",
    "RIO_GRANDE": "A802",
    "RIO_NEGRINHO": "A862",
    "RIO_PARDO": "A813",
    "RIO_PARDO_DE_MINAS": "A551",
    "RIO_SONO": "A050",
    "RIO_URUBU": "A125",
    "RIO_VERDE": "A025",
    "RONDON_DO_PARA": "A214",
    "RONDONOPOLIS": "A907",
    "ROSARIO_OESTE": "A944",
    "S._G._DA_CACHOEIRA": "A134",
    "S.J._DO_RIO_CLARO": "A903",
    "SACRAMENTO": "A525",
    "SALGUEIRO": "A370",
    "SALINAS": "A552",
    "SALINOPOLIS": "A215",
    "SALTO_DO_CEU": "A936",
    "SALVADOR": "A401",
    "SALVADOR:_RADIO_FAROL": "A456",
    "SANTA_CRUZ": "A367",
    "SANTA_FE_DO_ARAGUAIA": "A048",
    "SANTA_MARIA": "A803",
    "SANTA_MARIA_DAS_BARREIRAS": "A256",
    "SANTA_MARIA_MADALENA": "A630",
    "SANTA_RITA_DE_CASSIA": "A415",
    "SANTA_ROSA": "A810",
    "SANTA_ROSA_DO_TOCANTINS": "A052",
    "SANTA_TERESA": "A613",
    "SANTANA_DO_ARAGUAIA": "A233",
    "SANTANA_DO_LIVRAMENTO": "A804",
    "SANTAREM": "A250",
    "SANTIAGO": "A833",
    "SANTO_ANTONIO_DO_LESTE": "A931",
    "SANTO_AUGUSTO": "A805",
    "SAO_BORJA": "A830",
    "SAO_CARLOS": "A711",
    "SAO_FELIX_DO_ARAGUAIA": "A921",
    "SAO_FELIX_DO_XINGU": "A216",
    "SAO_GABRIEL": "A832",
    "SAO_GABRIEL_DO_OESTE": "A732",
    "SAO_GONCALO": "A333",
    "SAO_JOAO_DEL_REI": "A514",
    "SAO_JOAO_DO_PIAUI": "A331",
    "SAO_JOAQUIM": "A815",
    "SAO_JOSE_DO_XINGU": "A942",
    "SAO_JOSE_DOS_AUSENTES": "A829",
    "SAO_LUIS": "A203",
    "SAO_LUIS_DO_QUITUNDE": "A356",
    "SAO_LUIZ_DO_PARAITINGA": "A740",
    "SAO_LUIZ_GONZAGA": "A852",
    "SAO_MATEUS": "A616",
    "SAO_MATEUS_DO_SUL": "A874",
    "SAO_MIGUEL_ARCANJO": "A715",
    "SAO_MIGUEL_DO_ARAGUAIA": "A031",
    "SAO_MIGUEL_DO_OESTE": "A857",
    "SAO_PAULO___INTERLAGOS": "A771",
    "SAO_PAULO___MIRANTE": "A701",
    "SAO_RAIMUNDO_NONATO": "A345",
    "SAO_ROMAO": "A547",
    "SAO_SEBASTIAO_DO_PARAISO": "A561",
    "SAO_SIMAO": "A770",
    "SAO_SIMAO": "A011",
    "SAO_VICENTE_DO_SUL": "A889",
    "SAPEZAL": "A911",
    "SAQUAREMA___SAMPAIO_CORREIA": "A667",
    "SENHOR_DO_BONFIM": "A428",
    "SERAFINA_CORREA": "A894",
    "SEROPEDICA_ECOLOGIA_AGRICOLA": "A601",
    "SERRA_DOS_AIMORES": "A522",
    "SERRA_DOS_CARAJAS": "A230",
    "SERRA_NOVA_DOURADA": "A943",
    "SERRA_TALHADA": "A350",
    "SERRINHA": "A441",
    "SETE_LAGOAS": "A569",
    "SETE_QUEDAS": "A751",
    "SIDROLANDIA": "A754",
    "SILVA_JARDIM": "A659",
    "SILVANIA": "A037",
    "SINOP": "A917",
    "SOBRAL": "A306",
    "SOLEDADE": "A837",
    "SONORA": "A761",
    "SOROCABA": "A713",
    "SORRISO": "A904",
    "SOURE": "A227",
    "SURUBIM": "A328",
    "Santa_Vitoria_do_Palmar___Barra_do_Chui": "A899",
    "TANGARA_DA_SERRA": "A902",
    "TAUA": "A324",
    "TAUBATE": "A728",
    "TEOFILO_OTONI": "A527",
    "TERESINA": "A312",
    "TERESOPOLIS_PARQUE_NACIONAL": "A618",
    "TEUTONIA": "A882",
    "TIANGUA": "A368",
    "TIMOTEO": "A511",
    "TOME_ACU": "A213",
    "TORRES": "A808",
    "TRAMANDAI": "A834",
    "TRES_LAGOAS": "A704",
    "TRES_MARIAS": "A528",
    "TRES_RIOS": "A625",
    "TUCUMA": "A234",
    "TUCURUI": "A229",
    "TUPA": "A768",
    "TUPANCIRETA": "A886",
    "TURIACU": "A219",
    "UBERABA": "A568",
    "UBERLANDIA": "A507",
    "UNA": "A437",
    "UNAI": "A542",
    "URUCARA": "A124",
    "URUCUI": "A346",
    "URUGUAIANA": "A809",
    "URUSSANGA": "A814",
    "VACARIA": "A880",
    "VALENCA": "A611",
    "VALENCA": "A444",
    "VALENCA_DO_PIAUI": "A363",
    "VALPARAISO": "A734",
    "VARGINHA": "A515",
    "VENDA_NOVA_DO_IMIGRANTE": "A633",
    "VENTANIA": "A872",
    "VICOSA": "A510",
    "VILA_BELA_DA_SANTISSIMA_TRINDADE": "A922",
    "VILA_VELHA": "A634",
    "VILHENA": "A938",
    "VITORIA": "A612",
    "VITORIA_DA_CONQUISTA": "A414",
    "XANXERE": "A858",
    "XINGUARA": "A247",
    "ZE_DOCA": "A255"
}

# %%
len(cidades)
# Out:
# 543

# %%
paths = []

for cidade, codigo in cidades.items():
    path = f"../data/raw/Dados_INMET/dados_{codigo}_D_2023-01-01_2023-12-31.csv"
    paths.append((cidade, path))

# Visualizando os paths
for cidade, path in paths:
    print(f"{cidade}: {path}")
# Out:
# ABROLHOS: ../data/raw/Dados_INMET/dados_A422_D_2023-01-01_2023-12-31.csv
# ACARAU: ../data/raw/Dados_INMET/dados_A360_D_2023-01-01_2023-12-31.csv
# AFONSO_CLAUDIO: ../data/raw/Dados_INMET/dados_A657_D_2023-01-01_2023-12-31.csv
# AGUA_BOA: ../data/raw/Dados_INMET/dados_A908_D_2023-01-01_2023-12-31.csv
# AGUA_CLARA: ../data/raw/Dados_INMET/dados_A756_D_2023-01-01_2023-12-31.csv
# AGUAS_EMENDADAS: ../data/raw/Dados_INMET/dados_A045_D_2023-01-01_2023-12-31.csv
# AGUAS_VERMELHAS: ../data/raw/Dados_INMET/dados_A549_D_2023-01-01_2023-12-31.csv
# AIMORES: ../data/raw/Dados_INMET/dados_A534_D_2023-01-01_2023-12-31.csv
# ALEGRE: ../data/raw/Dados_INMET/dados_A617_D_2023-01-01_2023-12-31.csv
# ALEGRETE: ../data/raw/Dados_INMET/dados_A826_D_2023-01-01_2023-12-31.csv
# ALFREDO_CHAVES: ../data/raw/Dados_INMET/dados_A615_D_2023-01-01_2023-12-31.csv
# ALMAS: ../data/raw/Dados_INMET/dados_A053_D_2023-01-01_2023-12-31.csv
# ALMENARA: ../data/raw/Dados_INMET/dados_A508_D_2023-01-01_2023-12-31.csv
# ...

# %%
PATH_ABROLHOS = "../data/raw/Dados_INMET/dados_A422_D_2023-01-01_2023-12-31.csv"
PATH_ACARAU = "../data/raw/Dados_INMET/dados_A360_D_2023-01-01_2023-12-31.csv"
PATH_AFONSO_CLAUDIO = "../data/raw/Dados_INMET/dados_A657_D_2023-01-01_2023-12-31.csv"
PATH_AGUA_BOA = "../data/raw/Dados_INMET/dados_A908_D_2023-01-01_2023-12-31.csv"
PATH_AGUA_CLARA = "../data/raw/Dados_INMET/dados_A756_D_2023-01-01_2023-12-31.csv"
PATH_AGUAS_EMENDADAS = "../data/raw/Dados_INMET/dados_A045_D_2023-01-01_2023-12-31.csv"
PATH_AGUAS_VERMELHAS = "../data/raw/Dados_INMET/dados_A549_D_2023-01-01_2023-12-31.csv"
PATH_AIMORES = "../data/raw/Dados_INMET/dados_A534_D_2023-01-01_2023-12-31.csv"
PATH_ALEGRE = "../data/raw/Dados_INMET/dados_A617_D_2023-01-01_2023-12-31.csv"
PATH_ALEGRETE = "../data/raw/Dados_INMET/dados_A826_D_2023-01-01_2023-12-31.csv"
PATH_ALFREDO_CHAVES = "../data/raw/Dados_INMET/dados_A615_D_2023-01-01_2023-12-31.csv"
PATH_ALMAS = "../data/raw/Dados_INMET/dados_A053_D_2023-01-01_2023-12-31.csv"
PATH_ALMENARA = "../data/raw/Dados_INMET/dados_A508_D_2023-01-01_2023-12-31.csv"
PATH_ALTA_FLORESTA = "../data/raw/Dados_INMET/dados_A924_D_2023-01-01_2023-12-31.csv"
PATH_ALTAMIRA = "../data/raw/Dados_INMET/dados_A253_D_2023-01-01_2023-12-31.csv"
PATH_ALTO_ARAGUAIA = "../data/raw/Dados_INMET/dados_A909_D_2023-01-01_2023-12-31.csv"
PATH_ALTO_PARAISO_DE_GOIAS = "../data/raw/Dados_INMET/dados_A024_D_2023-01-01_2023-12-31.csv"
PATH_ALTO_PARNAIBA = "../data/raw/Dados_INMET/dados_A223_D_2023-01-01_2023-12-31.csv"
PATH_ALTO_TAQUARI = "../data/raw/Dados_INMET/dados_A934_D_2023-01-01_2023-12-31.csv"
PATH_ALVORADA_DO_GURGUEIA = "../data/raw/Dados_INMET/dados_A336_D_2023-01-01_2023-12-31.csv"
PATH_AMAMBAI = "../data/raw/Dados_INMET/dados_A750_D_2023-01-01_2023-12-31.csv"
PATH_AMARGOSA = "../data/raw/Dados_INMET/dados_A434_D_2023-01-01_2023-12-31.csv"
PATH_ANGICAL_DO_PIAUI = "../data/raw/Dados_INMET/dados_A377_D_2023-01-01_2023-12-31.csv"
PATH_ANGRA_DOS_REIS = "../data/raw/Dados_INMET/dados_A628_D_2023-01-01_2023-12-31.csv"
PATH_APIACAS = "../data/raw/Dados_INMET/dados_A910_D_2023-01-01_2023-12-31.csv"
PATH_APODI = "../data/raw/Dados_INMET/dados_A340_D_2023-01-01_2023-12-31.csv"
PATH_APUI = "../data/raw/Dados_INMET/dados_A113_D_2023-01-01_2023-12-31.csv"
PATH_AQUIDAUANA = "../data/raw/Dados_INMET/dados_A719_D_2023-01-01_2023-12-31.csv"
PATH_ARACAJU = "../data/raw/Dados_INMET/dados_A409_D_2023-01-01_2023-12-31.csv"
PATH_ARACUAI = "../data/raw/Dados_INMET/dados_A566_D_2023-01-01_2023-12-31.csv"
PATH_ARAGARCAS = "../data/raw/Dados_INMET/dados_A013_D_2023-01-01_2023-12-31.csv"
PATH_ARAGUACU = "../data/raw/Dados_INMET/dados_A054_D_2023-01-01_2023-12-31.csv"
PATH_ARAGUAINA = "../data/raw/Dados_INMET/dados_A021_D_2023-01-01_2023-12-31.csv"
PATH_ARAGUATINS = "../data/raw/Dados_INMET/dados_A044_D_2023-01-01_2023-12-31.csv"
PATH_ARAPIRACA = "../data/raw/Dados_INMET/dados_A353_D_2023-01-01_2023-12-31.csv"
PATH_ARARANGUA = "../data/raw/Dados_INMET/dados_A867_D_2023-01-01_2023-12-31.csv"
PATH_ARAXA = "../data/raw/Dados_INMET/dados_A505_D_2023-01-01_2023-12-31.csv"
PATH_ARCO_VERDE = "../data/raw/Dados_INMET/dados_A309_D_2023-01-01_2023-12-31.csv"
PATH_AREIA = "../data/raw/Dados_INMET/dados_A310_D_2023-01-01_2023-12-31.csv"
PATH_ARIQUEMES = "../data/raw/Dados_INMET/dados_A940_D_2023-01-01_2023-12-31.csv"
PATH_ARIRANHA = "../data/raw/Dados_INMET/dados_A736_D_2023-01-01_2023-12-31.csv"
PATH_ARRAIAL_DO_CABO = "../data/raw/Dados_INMET/dados_A606_D_2023-01-01_2023-12-31.csv"
PATH_AUTAZES = "../data/raw/Dados_INMET/dados_A120_D_2023-01-01_2023-12-31.csv"
PATH_AVARE = "../data/raw/Dados_INMET/dados_A725_D_2023-01-01_2023-12-31.csv"
PATH_BACABAL = "../data/raw/Dados_INMET/dados_A220_D_2023-01-01_2023-12-31.csv"
PATH_BAGE = "../data/raw/Dados_INMET/dados_A827_D_2023-01-01_2023-12-31.csv"
PATH_BAIXA_GRANDE_DO_RIBEIRO = "../data/raw/Dados_INMET/dados_A375_D_2023-01-01_2023-12-31.csv"
PATH_BALSAS = "../data/raw/Dados_INMET/dados_A204_D_2023-01-01_2023-12-31.csv"
PATH_BAMBUI = "../data/raw/Dados_INMET/dados_A565_D_2023-01-01_2023-12-31.csv"
PATH_BARBACENA = "../data/raw/Dados_INMET/dados_A502_D_2023-01-01_2023-12-31.csv"
PATH_BARBALHA = "../data/raw/Dados_INMET/dados_A315_D_2023-01-01_2023-12-31.csv"
PATH_BARCELOS = "../data/raw/Dados_INMET/dados_A128_D_2023-01-01_2023-12-31.csv"
PATH_BARRA = "../data/raw/Dados_INMET/dados_A429_D_2023-01-01_2023-12-31.csv"
PATH_BARRA_BONITA = "../data/raw/Dados_INMET/dados_A741_D_2023-01-01_2023-12-31.csv"
PATH_BARRA_DO_CORDA = "../data/raw/Dados_INMET/dados_A221_D_2023-01-01_2023-12-31.csv"
PATH_BARRA_DO_TURVO = "../data/raw/Dados_INMET/dados_A746_D_2023-01-01_2023-12-31.csv"
PATH_BARREIRAS = "../data/raw/Dados_INMET/dados_A402_D_2023-01-01_2023-12-31.csv"
PATH_BARRETOS = "../data/raw/Dados_INMET/dados_A748_D_2023-01-01_2023-12-31.csv"
PATH_BARUERI = "../data/raw/Dados_INMET/dados_A755_D_2023-01-01_2023-12-31.csv"
PATH_BATAGUASSU = "../data/raw/Dados_INMET/dados_A759_D_2023-01-01_2023-12-31.csv"
PATH_BAURU = "../data/raw/Dados_INMET/dados_A705_D_2023-01-01_2023-12-31.csv"
PATH_BEBEDOURO = "../data/raw/Dados_INMET/dados_A764_D_2023-01-01_2023-12-31.csv"
PATH_BELEM = "../data/raw/Dados_INMET/dados_A201_D_2023-01-01_2023-12-31.csv"
PATH_BELMONTE = "../data/raw/Dados_INMET/dados_A447_D_2023-01-01_2023-12-31.csv"
PATH_BELO_HORIZONTE__PAMPLHA = "../data/raw/Dados_INMET/dados_A521_D_2023-01-01_2023-12-31.csv"
PATH_BELO_HORIZONTE___CERCADINHO = "../data/raw/Dados_INMET/dados_F501_D_2023-01-01_2023-12-31.csv"
PATH_BENTO_GONCALVES = "../data/raw/Dados_INMET/dados_A840_D_2023-01-01_2023-12-31.csv"
PATH_BERTIOGA = "../data/raw/Dados_INMET/dados_A765_D_2023-01-01_2023-12-31.csv"
PATH_BOA_VISTA = "../data/raw/Dados_INMET/dados_A135_D_2023-01-01_2023-12-31.csv"
PATH_BOCA_DO_ACRE = "../data/raw/Dados_INMET/dados_A110_D_2023-01-01_2023-12-31.csv"
PATH_BOM_JARDIM_DA_SERRA___MORRO_DA_IGREJA = "../data/raw/Dados_INMET/dados_A845_D_2023-01-01_2023-12-31.csv"
PATH_BOM_JESUS_DA_LAPA = "../data/raw/Dados_INMET/dados_A418_D_2023-01-01_2023-12-31.csv"
PATH_BOM_JESUS_DO_PIAUI = "../data/raw/Dados_INMET/dados_A326_D_2023-01-01_2023-12-31.csv"
PATH_BRAGANCA = "../data/raw/Dados_INMET/dados_A226_D_2023-01-01_2023-12-31.csv"
PATH_BRAGANCA_PAULISTA = "../data/raw/Dados_INMET/dados_A744_D_2023-01-01_2023-12-31.csv"
PATH_BRASILIA = "../data/raw/Dados_INMET/dados_A001_D_2023-01-01_2023-12-31.csv"
PATH_BRASNORTE__NOVO_MUNDO = "../data/raw/Dados_INMET/dados_A927_D_2023-01-01_2023-12-31.csv"
PATH_BRAZLANDIA = "../data/raw/Dados_INMET/dados_A042_D_2023-01-01_2023-12-31.csv"
PATH_BREJO_GRANDE = "../data/raw/Dados_INMET/dados_A421_D_2023-01-01_2023-12-31.csv"
PATH_BREVES = "../data/raw/Dados_INMET/dados_A228_D_2023-01-01_2023-12-31.csv"
PATH_BRUMADO = "../data/raw/Dados_INMET/dados_A433_D_2023-01-01_2023-12-31.csv"
PATH_BURITICUPU = "../data/raw/Dados_INMET/dados_A238_D_2023-01-01_2023-12-31.csv"
PATH_BURITIRAMA = "../data/raw/Dados_INMET/dados_A432_D_2023-01-01_2023-12-31.csv"
PATH_BURITIS = "../data/raw/Dados_INMET/dados_A544_D_2023-01-01_2023-12-31.csv"
PATH_CABACEIRAS = "../data/raw/Dados_INMET/dados_A348_D_2023-01-01_2023-12-31.csv"
PATH_CABROBO = "../data/raw/Dados_INMET/dados_A329_D_2023-01-01_2023-12-31.csv"
PATH_CACADOR = "../data/raw/Dados_INMET/dados_A859_D_2023-01-01_2023-12-31.csv"
PATH_CACAPAVA_DO_SUL = "../data/raw/Dados_INMET/dados_A812_D_2023-01-01_2023-12-31.csv"
PATH_CACHOEIRA_PAULISTA = "../data/raw/Dados_INMET/dados_A769_D_2023-01-01_2023-12-31.csv"
PATH_CACOAL = "../data/raw/Dados_INMET/dados_A939_D_2023-01-01_2023-12-31.csv"
PATH_CAIAPONIA = "../data/raw/Dados_INMET/dados_A023_D_2023-01-01_2023-12-31.csv"
PATH_CAICO = "../data/raw/Dados_INMET/dados_A316_D_2023-01-01_2023-12-31.csv"
PATH_CALCANHAR = "../data/raw/Dados_INMET/dados_A344_D_2023-01-01_2023-12-31.csv"
PATH_CALDAS = "../data/raw/Dados_INMET/dados_A530_D_2023-01-01_2023-12-31.csv"
PATH_CAMAQUA = "../data/raw/Dados_INMET/dados_A838_D_2023-01-01_2023-12-31.csv"
PATH_CAMARATUBA = "../data/raw/Dados_INMET/dados_A352_D_2023-01-01_2023-12-31.csv"
PATH_CAMBARA_DO_SUL = "../data/raw/Dados_INMET/dados_A897_D_2023-01-01_2023-12-31.csv"
PATH_CAMBUCI = "../data/raw/Dados_INMET/dados_A604_D_2023-01-01_2023-12-31.csv"
PATH_CAMETA = "../data/raw/Dados_INMET/dados_A236_D_2023-01-01_2023-12-31.csv"
PATH_CAMPINA_DA_LAGOA = "../data/raw/Dados_INMET/dados_B803_D_2023-01-01_2023-12-31.csv"
PATH_CAMPINA_GRANDE = "../data/raw/Dados_INMET/dados_A313_D_2023-01-01_2023-12-31.csv"
PATH_CAMPINA_VERDE = "../data/raw/Dados_INMET/dados_A519_D_2023-01-01_2023-12-31.csv"
PATH_CAMPO_BOM = "../data/raw/Dados_INMET/dados_A884_D_2023-01-01_2023-12-31.csv"
PATH_CAMPO_GRANDE = "../data/raw/Dados_INMET/dados_A702_D_2023-01-01_2023-12-31.csv"
PATH_CAMPO_MAIOR = "../data/raw/Dados_INMET/dados_A376_D_2023-01-01_2023-12-31.csv"
PATH_CAMPO_NOVO_DOS_PARECIS = "../data/raw/Dados_INMET/dados_A905_D_2023-01-01_2023-12-31.csv"
PATH_CAMPO_VERDE = "../data/raw/Dados_INMET/dados_A912_D_2023-01-01_2023-12-31.csv"
PATH_CAMPOS_DO_JORDAO = "../data/raw/Dados_INMET/dados_A706_D_2023-01-01_2023-12-31.csv"
PATH_CAMPOS_DOS_GOYTACAZES = "../data/raw/Dados_INMET/dados_A607_D_2023-01-01_2023-12-31.csv"
PATH_CAMPOS_DOS_GOYTACAZES___SAO_TOME = "../data/raw/Dados_INMET/dados_A620_D_2023-01-01_2023-12-31.csv"
PATH_CAMPOS_LINDOS = "../data/raw/Dados_INMET/dados_A043_D_2023-01-01_2023-12-31.csv"
PATH_CAMPOS_NOVOS = "../data/raw/Dados_INMET/dados_A898_D_2023-01-01_2023-12-31.csv"
PATH_CAMPOS_SALES = "../data/raw/Dados_INMET/dados_A347_D_2023-01-01_2023-12-31.csv"
PATH_CANELA = "../data/raw/Dados_INMET/dados_A879_D_2023-01-01_2023-12-31.csv"
PATH_CANGUCU = "../data/raw/Dados_INMET/dados_A811_D_2023-01-01_2023-12-31.csv"
PATH_CANTO_DO_BURITI = "../data/raw/Dados_INMET/dados_A365_D_2023-01-01_2023-12-31.csv"
PATH_CAPAO_DO_LEAO_PELOTAS = "../data/raw/Dados_INMET/dados_A887_D_2023-01-01_2023-12-31.csv"
PATH_CAPELINHA = "../data/raw/Dados_INMET/dados_A541_D_2023-01-01_2023-12-31.csv"
PATH_CAPITAO_POCO = "../data/raw/Dados_INMET/dados_A248_D_2023-01-01_2023-12-31.csv"
PATH_CARACOL = "../data/raw/Dados_INMET/dados_A337_D_2023-01-01_2023-12-31.csv"
PATH_CARATINGA = "../data/raw/Dados_INMET/dados_A554_D_2023-01-01_2023-12-31.csv"
PATH_CARAVELAS = "../data/raw/Dados_INMET/dados_A405_D_2023-01-01_2023-12-31.csv"
PATH_CARLINDA = "../data/raw/Dados_INMET/dados_A926_D_2023-01-01_2023-12-31.csv"
PATH_CARMO = "../data/raw/Dados_INMET/dados_A629_D_2023-01-01_2023-12-31.csv"
PATH_CAROLINA = "../data/raw/Dados_INMET/dados_A205_D_2023-01-01_2023-12-31.csv"
PATH_CARUARU = "../data/raw/Dados_INMET/dados_A341_D_2023-01-01_2023-12-31.csv"
PATH_CASA_BRANCA = "../data/raw/Dados_INMET/dados_A738_D_2023-01-01_2023-12-31.csv"
PATH_CASSILANDIA = "../data/raw/Dados_INMET/dados_A742_D_2023-01-01_2023-12-31.csv"
PATH_CASTANHAL = "../data/raw/Dados_INMET/dados_A202_D_2023-01-01_2023-12-31.csv"
PATH_CASTELO_DO_PIAUI = "../data/raw/Dados_INMET/dados_A361_D_2023-01-01_2023-12-31.csv"
PATH_CASTRO = "../data/raw/Dados_INMET/dados_A819_D_2023-01-01_2023-12-31.csv"
PATH_CATALAO = "../data/raw/Dados_INMET/dados_A034_D_2023-01-01_2023-12-31.csv"
PATH_CAXIAS = "../data/raw/Dados_INMET/dados_A237_D_2023-01-01_2023-12-31.csv"
PATH_CHAPADA_GAUCHA = "../data/raw/Dados_INMET/dados_A548_D_2023-01-01_2023-12-31.csv"
PATH_CHAPADAO_DO_SUL = "../data/raw/Dados_INMET/dados_A730_D_2023-01-01_2023-12-31.csv"
PATH_CHAPADINHA = "../data/raw/Dados_INMET/dados_A206_D_2023-01-01_2023-12-31.csv"
PATH_CHAPECO = "../data/raw/Dados_INMET/dados_A895_D_2023-01-01_2023-12-31.csv"
PATH_CIDADE_GAUCHA = "../data/raw/Dados_INMET/dados_A869_D_2023-01-01_2023-12-31.csv"
PATH_CLEVELANDIA = "../data/raw/Dados_INMET/dados_A876_D_2023-01-01_2023-12-31.csv"
PATH_COARI = "../data/raw/Dados_INMET/dados_A117_D_2023-01-01_2023-12-31.csv"
PATH_COLINAS = "../data/raw/Dados_INMET/dados_A222_D_2023-01-01_2023-12-31.csv"
PATH_COLINAS_DO_TOCANTINS = "../data/raw/Dados_INMET/dados_A049_D_2023-01-01_2023-12-31.csv"
PATH_COLOMBO = "../data/raw/Dados_INMET/dados_B806_D_2023-01-01_2023-12-31.csv"
PATH_COMODORO = "../data/raw/Dados_INMET/dados_A913_D_2023-01-01_2023-12-31.csv"
PATH_CONCEICAO_DAS_ALAGOAS = "../data/raw/Dados_INMET/dados_A520_D_2023-01-01_2023-12-31.csv"
PATH_CONCEICAO_DO_ARAGUAIA = "../data/raw/Dados_INMET/dados_A241_D_2023-01-01_2023-12-31.csv"
PATH_CONDE = "../data/raw/Dados_INMET/dados_A431_D_2023-01-01_2023-12-31.csv"
PATH_CORONEL_PACHECO = "../data/raw/Dados_INMET/dados_A557_D_2023-01-01_2023-12-31.csv"
PATH_CORRENTE = "../data/raw/Dados_INMET/dados_A374_D_2023-01-01_2023-12-31.csv"
PATH_CORRENTINA = "../data/raw/Dados_INMET/dados_A416_D_2023-01-01_2023-12-31.csv"
PATH_CORUMBA = "../data/raw/Dados_INMET/dados_A724_D_2023-01-01_2023-12-31.csv"
PATH_CORURIPE = "../data/raw/Dados_INMET/dados_A355_D_2023-01-01_2023-12-31.csv"
PATH_COSTA_RICA = "../data/raw/Dados_INMET/dados_A760_D_2023-01-01_2023-12-31.csv"
PATH_COTRIGUACU = "../data/raw/Dados_INMET/dados_A919_D_2023-01-01_2023-12-31.csv"
PATH_COXIM = "../data/raw/Dados_INMET/dados_A720_D_2023-01-01_2023-12-31.csv"
PATH_CRATEUS = "../data/raw/Dados_INMET/dados_A342_D_2023-01-01_2023-12-31.csv"
PATH_CRISTALINA = "../data/raw/Dados_INMET/dados_A036_D_2023-01-01_2023-12-31.csv"
PATH_CRISTALINA_FAZENDA_SANTA_MONICA = "../data/raw/Dados_INMET/dados_A056_D_2023-01-01_2023-12-31.csv"
PATH_CRUZ_ALTA = "../data/raw/Dados_INMET/dados_A853_D_2023-01-01_2023-12-31.csv"
PATH_CRUZ_DAS_ALMAS = "../data/raw/Dados_INMET/dados_A406_D_2023-01-01_2023-12-31.csv"
PATH_CRUZEIRO_DO_SUL = "../data/raw/Dados_INMET/dados_A108_D_2023-01-01_2023-12-31.csv"
PATH_CUIABA = "../data/raw/Dados_INMET/dados_A901_D_2023-01-01_2023-12-31.csv"
PATH_CURACA = "../data/raw/Dados_INMET/dados_A448_D_2023-01-01_2023-12-31.csv"
PATH_ERECHIM = "../data/raw/Dados_INMET/dados_A828_D_2023-01-01_2023-12-31.csv"
PATH_ESPINOSA = "../data/raw/Dados_INMET/dados_A543_D_2023-01-01_2023-12-31.csv"
PATH_ESTREITO = "../data/raw/Dados_INMET/dados_A224_D_2023-01-01_2023-12-31.csv"
PATH_EUCLIDES_DA_CUNHA = "../data/raw/Dados_INMET/dados_A442_D_2023-01-01_2023-12-31.csv"
PATH_FAROL_de_SANTANA = "../data/raw/Dados_INMET/dados_A217_D_2023-01-01_2023-12-31.csv"
PATH_FEIJO = "../data/raw/Dados_INMET/dados_A138_D_2023-01-01_2023-12-31.csv"
PATH_FEIRA_DE_SANTANA = "../data/raw/Dados_INMET/dados_A413_D_2023-01-01_2023-12-31.csv"
PATH_FLORESTA = "../data/raw/Dados_INMET/dados_A351_D_2023-01-01_2023-12-31.csv"
PATH_FLORESTAL = "../data/raw/Dados_INMET/dados_A535_D_2023-01-01_2023-12-31.csv"
PATH_FLORIANO = "../data/raw/Dados_INMET/dados_A311_D_2023-01-01_2023-12-31.csv"
PATH_FLORIANOPOLIS = "../data/raw/Dados_INMET/dados_A806_D_2023-01-01_2023-12-31.csv"
PATH_FORMIGA = "../data/raw/Dados_INMET/dados_A524_D_2023-01-01_2023-12-31.csv"
PATH_FORMOSA_DO_RIO_PRETO = "../data/raw/Dados_INMET/dados_A452_D_2023-01-01_2023-12-31.csv"
PATH_FORMOSO_DO_ARAGUAIA = "../data/raw/Dados_INMET/dados_A039_D_2023-01-01_2023-12-31.csv"
PATH_FORTALEZA = "../data/raw/Dados_INMET/dados_A305_D_2023-01-01_2023-12-31.csv"
PATH_FOZ_DO_IGUACU = "../data/raw/Dados_INMET/dados_A846_D_2023-01-01_2023-12-31.csv"
PATH_FRANCA = "../data/raw/Dados_INMET/dados_A708_D_2023-01-01_2023-12-31.csv"
PATH_FREDERICO_WESTPHALEN = "../data/raw/Dados_INMET/dados_A854_D_2023-01-01_2023-12-31.csv"
PATH_GAMA__PONT_ALTA = "../data/raw/Dados_INMET/dados_A046_D_2023-01-01_2023-12-31.csv"
PATH_GARANHUNS = "../data/raw/Dados_INMET/dados_A322_D_2023-01-01_2023-12-31.csv"
PATH_GAUCHA_DO_NORTE = "../data/raw/Dados_INMET/dados_A930_D_2023-01-01_2023-12-31.csv"
PATH_GENERAL_CARNEIRO = "../data/raw/Dados_INMET/dados_A875_D_2023-01-01_2023-12-31.csv"
PATH_GILBUES = "../data/raw/Dados_INMET/dados_A364_D_2023-01-01_2023-12-31.csv"
PATH_GOIANESIA = "../data/raw/Dados_INMET/dados_A022_D_2023-01-01_2023-12-31.csv"
PATH_GOIANIA = "../data/raw/Dados_INMET/dados_A002_D_2023-01-01_2023-12-31.csv"
PATH_GOIAS = "../data/raw/Dados_INMET/dados_A014_D_2023-01-01_2023-12-31.csv"
PATH_GOIOERE = "../data/raw/Dados_INMET/dados_A825_D_2023-01-01_2023-12-31.csv"
PATH_GOVERNADOR_VALADARES = "../data/raw/Dados_INMET/dados_A532_D_2023-01-01_2023-12-31.csv"
PATH_GRAJAU = "../data/raw/Dados_INMET/dados_A207_D_2023-01-01_2023-12-31.csv"
PATH_GUANAMBI = "../data/raw/Dados_INMET/dados_A426_D_2023-01-01_2023-12-31.csv"
PATH_GUANHAES = "../data/raw/Dados_INMET/dados_A533_D_2023-01-01_2023-12-31.csv"
PATH_GUARAMIRANGA = "../data/raw/Dados_INMET/dados_A314_D_2023-01-01_2023-12-31.csv"
PATH_GUARANTA_DO_NORTE = "../data/raw/Dados_INMET/dados_A906_D_2023-01-01_2023-12-31.csv"
PATH_GUARDA_MOR = "../data/raw/Dados_INMET/dados_A546_D_2023-01-01_2023-12-31.csv"
PATH_GUIRATINGA = "../data/raw/Dados_INMET/dados_A932_D_2023-01-01_2023-12-31.csv"
PATH_GURUPI = "../data/raw/Dados_INMET/dados_A019_D_2023-01-01_2023-12-31.csv"
PATH_HUMAITA = "../data/raw/Dados_INMET/dados_A112_D_2023-01-01_2023-12-31.csv"
PATH_IBIMIRIM = "../data/raw/Dados_INMET/dados_A349_D_2023-01-01_2023-12-31.csv"
PATH_IBIRITE__ROLAMOCA = "../data/raw/Dados_INMET/dados_A555_D_2023-01-01_2023-12-31.csv"
PATH_IBIRUBA = "../data/raw/Dados_INMET/dados_A883_D_2023-01-01_2023-12-31.csv"
PATH_IBITINGA = "../data/raw/Dados_INMET/dados_A737_D_2023-01-01_2023-12-31.csv"
PATH_IBOTIRAMA = "../data/raw/Dados_INMET/dados_A439_D_2023-01-01_2023-12-31.csv"
PATH_ICARAIMA = "../data/raw/Dados_INMET/dados_A824_D_2023-01-01_2023-12-31.csv"
PATH_IGUAPE = "../data/raw/Dados_INMET/dados_A712_D_2023-01-01_2023-12-31.csv"
PATH_IGUATU = "../data/raw/Dados_INMET/dados_A319_D_2023-01-01_2023-12-31.csv"
PATH_ILHEUS = "../data/raw/Dados_INMET/dados_A410_D_2023-01-01_2023-12-31.csv"
PATH_IMPERATRIZ = "../data/raw/Dados_INMET/dados_A225_D_2023-01-01_2023-12-31.csv"
PATH_INACIO_MARTINS = "../data/raw/Dados_INMET/dados_A823_D_2023-01-01_2023-12-31.csv"
PATH_INDAIAL = "../data/raw/Dados_INMET/dados_A817_D_2023-01-01_2023-12-31.csv"
PATH_IPANGUACU = "../data/raw/Dados_INMET/dados_A372_D_2023-01-01_2023-12-31.csv"
PATH_IPIAU = "../data/raw/Dados_INMET/dados_A445_D_2023-01-01_2023-12-31.csv"
PATH_IPORA = "../data/raw/Dados_INMET/dados_A028_D_2023-01-01_2023-12-31.csv"
PATH_IRECE = "../data/raw/Dados_INMET/dados_A424_D_2023-01-01_2023-12-31.csv"
PATH_ITABAIANA = "../data/raw/Dados_INMET/dados_A451_D_2023-01-01_2023-12-31.csv"
PATH_ITABAIANINHA = "../data/raw/Dados_INMET/dados_A417_D_2023-01-01_2023-12-31.csv"
PATH_ITABERABA = "../data/raw/Dados_INMET/dados_A408_D_2023-01-01_2023-12-31.csv"
PATH_ITACOATIARA = "../data/raw/Dados_INMET/dados_A121_D_2023-01-01_2023-12-31.csv"
PATH_ITAITUBA = "../data/raw/Dados_INMET/dados_A231_D_2023-01-01_2023-12-31.csv"
PATH_ITAJAI = "../data/raw/Dados_INMET/dados_A868_D_2023-01-01_2023-12-31.csv"
PATH_ITAMARAJU = "../data/raw/Dados_INMET/dados_A455_D_2023-01-01_2023-12-31.csv"
PATH_ITAOBIM = "../data/raw/Dados_INMET/dados_A550_D_2023-01-01_2023-12-31.csv"
PATH_ITAPACI = "../data/raw/Dados_INMET/dados_A015_D_2023-01-01_2023-12-31.csv"
PATH_ITAPETINGA = "../data/raw/Dados_INMET/dados_A446_D_2023-01-01_2023-12-31.csv"
PATH_ITAPEVA = "../data/raw/Dados_INMET/dados_A714_D_2023-01-01_2023-12-31.csv"
PATH_ITAPIPOCA = "../data/raw/Dados_INMET/dados_A359_D_2023-01-01_2023-12-31.csv"
PATH_ITAPIRA = "../data/raw/Dados_INMET/dados_A739_D_2023-01-01_2023-12-31.csv"
PATH_ITAPOA = "../data/raw/Dados_INMET/dados_A851_D_2023-01-01_2023-12-31.csv"
PATH_ITAPORANGA = "../data/raw/Dados_INMET/dados_A373_D_2023-01-01_2023-12-31.csv"
PATH_ITAQUIRAI = "../data/raw/Dados_INMET/dados_A752_D_2023-01-01_2023-12-31.csv"
PATH_ITAUBAL = "../data/raw/Dados_INMET/dados_A251_D_2023-01-01_2023-12-31.csv"
PATH_ITIQUIRA = "../data/raw/Dados_INMET/dados_A933_D_2023-01-01_2023-12-31.csv"
PATH_ITIRUCU = "../data/raw/Dados_INMET/dados_A407_D_2023-01-01_2023-12-31.csv"
PATH_ITUIUTABA = "../data/raw/Dados_INMET/dados_A512_D_2023-01-01_2023-12-31.csv"
PATH_ITUMBIARA = "../data/raw/Dados_INMET/dados_A035_D_2023-01-01_2023-12-31.csv"
PATH_ITUPORANGA = "../data/raw/Dados_INMET/dados_A863_D_2023-01-01_2023-12-31.csv"
PATH_ITUVERAVA = "../data/raw/Dados_INMET/dados_A753_D_2023-01-01_2023-12-31.csv"
PATH_IVAI = "../data/raw/Dados_INMET/dados_A818_D_2023-01-01_2023-12-31.csv"
PATH_IVINHEMA = "../data/raw/Dados_INMET/dados_A709_D_2023-01-01_2023-12-31.csv"
PATH_JACOBINA = "../data/raw/Dados_INMET/dados_A440_D_2023-01-01_2023-12-31.csv"
PATH_JAGUARAO = "../data/raw/Dados_INMET/dados_A836_D_2023-01-01_2023-12-31.csv"
PATH_JAGUARIBE = "../data/raw/Dados_INMET/dados_A358_D_2023-01-01_2023-12-31.csv"
PATH_JAGUARUANA = "../data/raw/Dados_INMET/dados_A339_D_2023-01-01_2023-12-31.csv"
PATH_JALES = "../data/raw/Dados_INMET/dados_A733_D_2023-01-01_2023-12-31.csv"
PATH_JANUARIA = "../data/raw/Dados_INMET/dados_A559_D_2023-01-01_2023-12-31.csv"
PATH_JAPIRA = "../data/raw/Dados_INMET/dados_A871_D_2023-01-01_2023-12-31.csv"
PATH_JARDIM = "../data/raw/Dados_INMET/dados_A758_D_2023-01-01_2023-12-31.csv"
PATH_JATAI = "../data/raw/Dados_INMET/dados_A016_D_2023-01-01_2023-12-31.csv"
PATH_JEREMOABO = "../data/raw/Dados_INMET/dados_A450_D_2023-01-01_2023-12-31.csv"
PATH_JOACABA = "../data/raw/Dados_INMET/dados_A841_D_2023-01-01_2023-12-31.csv"
PATH_JOAO_PESSOA = "../data/raw/Dados_INMET/dados_A320_D_2023-01-01_2023-12-31.csv"
PATH_JOAO_PINHEIRO = "../data/raw/Dados_INMET/dados_A553_D_2023-01-01_2023-12-31.csv"
PATH_JOAQUIM_TAVORA = "../data/raw/Dados_INMET/dados_A821_D_2023-01-01_2023-12-31.csv"
PATH_JOSE_BONIFACIO = "../data/raw/Dados_INMET/dados_A735_D_2023-01-01_2023-12-31.csv"
PATH_JUARA = "../data/raw/Dados_INMET/dados_A914_D_2023-01-01_2023-12-31.csv"
PATH_JUINA = "../data/raw/Dados_INMET/dados_A920_D_2023-01-01_2023-12-31.csv"
PATH_JUTI = "../data/raw/Dados_INMET/dados_A749_D_2023-01-01_2023-12-31.csv"
PATH_LABREA = "../data/raw/Dados_INMET/dados_A111_D_2023-01-01_2023-12-31.csv"
PATH_LAGES = "../data/raw/Dados_INMET/dados_A865_D_2023-01-01_2023-12-31.csv"
PATH_LAGOA_DA_CONFUSAO = "../data/raw/Dados_INMET/dados_A055_D_2023-01-01_2023-12-31.csv"
PATH_LAGOA_VERMELHA = "../data/raw/Dados_INMET/dados_A844_D_2023-01-01_2023-12-31.csv"
PATH_LARANJEIRAS_DO_SUL = "../data/raw/Dados_INMET/dados_B804_D_2023-01-01_2023-12-31.csv"
PATH_LENCOIS = "../data/raw/Dados_INMET/dados_A425_D_2023-01-01_2023-12-31.csv"
PATH_LINHARES = "../data/raw/Dados_INMET/dados_A614_D_2023-01-01_2023-12-31.csv"
PATH_LINS = "../data/raw/Dados_INMET/dados_A727_D_2023-01-01_2023-12-31.csv"
PATH_LUIZ_EDUARDO_MAGALHAES = "../data/raw/Dados_INMET/dados_A404_D_2023-01-01_2023-12-31.csv"
PATH_LUZIANIA = "../data/raw/Dados_INMET/dados_A012_D_2023-01-01_2023-12-31.csv"
PATH_LAGUNA___FAROL_DE_SANTA_MARTA = "../data/raw/Dados_INMET/dados_A866_D_2023-01-01_2023-12-31.csv"
PATH_MACAE = "../data/raw/Dados_INMET/dados_A608_D_2023-01-01_2023-12-31.csv"
PATH_MACAJUBA = "../data/raw/Dados_INMET/dados_A412_D_2023-01-01_2023-12-31.csv"
PATH_MACAPA = "../data/raw/Dados_INMET/dados_A249_D_2023-01-01_2023-12-31.csv"
PATH_MACAU = "../data/raw/Dados_INMET/dados_A317_D_2023-01-01_2023-12-31.csv"
PATH_MACEIO = "../data/raw/Dados_INMET/dados_A303_D_2023-01-01_2023-12-31.csv"
PATH_MACHADO = "../data/raw/Dados_INMET/dados_A567_D_2023-01-01_2023-12-31.csv"
PATH_MAJOR_VIEIRA = "../data/raw/Dados_INMET/dados_A864_D_2023-01-01_2023-12-31.csv"
PATH_MAL_CANDIDO_RONDON = "../data/raw/Dados_INMET/dados_A820_D_2023-01-01_2023-12-31.csv"
PATH_MANACAPURU = "../data/raw/Dados_INMET/dados_A119_D_2023-01-01_2023-12-31.csv"
PATH_MANAUS = "../data/raw/Dados_INMET/dados_A101_D_2023-01-01_2023-12-31.csv"
PATH_MANHUACU = "../data/raw/Dados_INMET/dados_A556_D_2023-01-01_2023-12-31.csv"
PATH_MANICORE = "../data/raw/Dados_INMET/dados_A133_D_2023-01-01_2023-12-31.csv"
PATH_MANTENA = "../data/raw/Dados_INMET/dados_A540_D_2023-01-01_2023-12-31.csv"
PATH_MARABA = "../data/raw/Dados_INMET/dados_A240_D_2023-01-01_2023-12-31.csv"
PATH_MARACAJU = "../data/raw/Dados_INMET/dados_A731_D_2023-01-01_2023-12-31.csv"
PATH_MARAU = "../data/raw/Dados_INMET/dados_A438_D_2023-01-01_2023-12-31.csv"
PATH_MARECHAL_THAUMATURGO = "../data/raw/Dados_INMET/dados_A137_D_2023-01-01_2023-12-31.csv"
PATH_MARIA_DA_FE = "../data/raw/Dados_INMET/dados_A531_D_2023-01-01_2023-12-31.csv"
PATH_MARIANOPOLIS_DO_TO = "../data/raw/Dados_INMET/dados_A041_D_2023-01-01_2023-12-31.csv"
PATH_MARILANDIA = "../data/raw/Dados_INMET/dados_A632_D_2023-01-01_2023-12-31.csv"
PATH_MARILIA = "../data/raw/Dados_INMET/dados_A763_D_2023-01-01_2023-12-31.csv"
PATH_MARINGA = "../data/raw/Dados_INMET/dados_A835_D_2023-01-01_2023-12-31.csv"
PATH_MATEIROS = "../data/raw/Dados_INMET/dados_A040_D_2023-01-01_2023-12-31.csv"
PATH_MAUES = "../data/raw/Dados_INMET/dados_A122_D_2023-01-01_2023-12-31.csv"
PATH_MEDICILANDIA = "../data/raw/Dados_INMET/dados_A209_D_2023-01-01_2023-12-31.csv"
PATH_MINA_DO_PALITO = "../data/raw/Dados_INMET/dados_A246_D_2023-01-01_2023-12-31.csv"
PATH_MINEIROS = "../data/raw/Dados_INMET/dados_A026_D_2023-01-01_2023-12-31.csv"
PATH_MIRANDA = "../data/raw/Dados_INMET/dados_A722_D_2023-01-01_2023-12-31.csv"
PATH_MOCAMBINHO = "../data/raw/Dados_INMET/dados_A539_D_2023-01-01_2023-12-31.csv"
PATH_MONTALVANIA = "../data/raw/Dados_INMET/dados_A526_D_2023-01-01_2023-12-31.csv"
PATH_MONTE_ALEGRE = "../data/raw/Dados_INMET/dados_A239_D_2023-01-01_2023-12-31.csv"
PATH_MONTE_ALEGRE_DE_GOIAS = "../data/raw/Dados_INMET/dados_A032_D_2023-01-01_2023-12-31.csv"
PATH_MONTE_VERDE = "../data/raw/Dados_INMET/dados_A509_D_2023-01-01_2023-12-31.csv"
PATH_MONTEIRO = "../data/raw/Dados_INMET/dados_A334_D_2023-01-01_2023-12-31.csv"
PATH_MONTES_CLAROS = "../data/raw/Dados_INMET/dados_A506_D_2023-01-01_2023-12-31.csv"
PATH_MORADA_NOVA = "../data/raw/Dados_INMET/dados_A332_D_2023-01-01_2023-12-31.csv"
PATH_MORRETES = "../data/raw/Dados_INMET/dados_A873_D_2023-01-01_2023-12-31.csv"
PATH_MORRINHOS = "../data/raw/Dados_INMET/dados_A003_D_2023-01-01_2023-12-31.csv"
PATH_MOSSORO = "../data/raw/Dados_INMET/dados_A318_D_2023-01-01_2023-12-31.csv"
PATH_MOSTARDAS = "../data/raw/Dados_INMET/dados_A878_D_2023-01-01_2023-12-31.csv"
PATH_MURIAE = "../data/raw/Dados_INMET/dados_A517_D_2023-01-01_2023-12-31.csv"
PATH_NATAL = "../data/raw/Dados_INMET/dados_A304_D_2023-01-01_2023-12-31.csv"
PATH_NHUMIRIM = "../data/raw/Dados_INMET/dados_A717_D_2023-01-01_2023-12-31.csv"
PATH_NITEROI = "../data/raw/Dados_INMET/dados_A627_D_2023-01-01_2023-12-31.csv"
PATH_NOSSA_SENHORA_DA_GLORIA = "../data/raw/Dados_INMET/dados_A453_D_2023-01-01_2023-12-31.csv"
PATH_NOVA_FATIMA = "../data/raw/Dados_INMET/dados_A842_D_2023-01-01_2023-12-31.csv"
PATH_NOVA_FRIBURGO___SALINAS = "../data/raw/Dados_INMET/dados_A624_D_2023-01-01_2023-12-31.csv"
PATH_NOVA_MARINGA = "../data/raw/Dados_INMET/dados_A928_D_2023-01-01_2023-12-31.csv"
PATH_NOVA_PORTEIRINHA__JANABA = "../data/raw/Dados_INMET/dados_A563_D_2023-01-01_2023-12-31.csv"
PATH_NOVA_TEBAS = "../data/raw/Dados_INMET/dados_A822_D_2023-01-01_2023-12-31.csv"
PATH_NOVA_UBIRATA = "../data/raw/Dados_INMET/dados_A929_D_2023-01-01_2023-12-31.csv"
PATH_NOVO_ARIPUANA = "../data/raw/Dados_INMET/dados_A144_D_2023-01-01_2023-12-31.csv"
PATH_NOVO_HORIZONTE = "../data/raw/Dados_INMET/dados_A816_D_2023-01-01_2023-12-31.csv"
PATH_NOVO_REPARTIMENTO = "../data/raw/Dados_INMET/dados_A235_D_2023-01-01_2023-12-31.csv"
PATH_OBIDOS = "../data/raw/Dados_INMET/dados_A232_D_2023-01-01_2023-12-31.csv"
PATH_OEIRAS = "../data/raw/Dados_INMET/dados_A354_D_2023-01-01_2023-12-31.csv"
PATH_OIAPOQUE = "../data/raw/Dados_INMET/dados_A242_D_2023-01-01_2023-12-31.csv"
PATH_OLIVEIRA = "../data/raw/Dados_INMET/dados_A570_D_2023-01-01_2023-12-31.csv"
PATH_OURICURI = "../data/raw/Dados_INMET/dados_A366_D_2023-01-01_2023-12-31.csv"
PATH_OURINHOS = "../data/raw/Dados_INMET/dados_A716_D_2023-01-01_2023-12-31.csv"
PATH_OURO_BRANCO = "../data/raw/Dados_INMET/dados_A513_D_2023-01-01_2023-12-31.csv"
PATH_PACAJA = "../data/raw/Dados_INMET/dados_A210_D_2023-01-01_2023-12-31.csv"
PATH_PALMARES = "../data/raw/Dados_INMET/dados_A357_D_2023-01-01_2023-12-31.csv"
PATH_PALMAS = "../data/raw/Dados_INMET/dados_A009_D_2023-01-01_2023-12-31.csv"
PATH_PALMEIRA_DAS_MISSOES = "../data/raw/Dados_INMET/dados_A856_D_2023-01-01_2023-12-31.csv"
PATH_PALMEIRA_DOS_INDIOS = "../data/raw/Dados_INMET/dados_A327_D_2023-01-01_2023-12-31.csv"
PATH_PAO_DE_ACUCAR = "../data/raw/Dados_INMET/dados_A323_D_2023-01-01_2023-12-31.csv"
PATH_PARACATU = "../data/raw/Dados_INMET/dados_A571_D_2023-01-01_2023-12-31.csv"
PATH_PARAGOMINAS = "../data/raw/Dados_INMET/dados_A212_D_2023-01-01_2023-12-31.csv"
PATH_PARANA = "../data/raw/Dados_INMET/dados_A010_D_2023-01-01_2023-12-31.csv"
PATH_PARANAIBA = "../data/raw/Dados_INMET/dados_A710_D_2023-01-01_2023-12-31.csv"
PATH_PARANAPOEMA = "../data/raw/Dados_INMET/dados_A850_D_2023-01-01_2023-12-31.csv"
PATH_PARANATINGA = "../data/raw/Dados_INMET/dados_A915_D_2023-01-01_2023-12-31.csv"
PATH_PARANOA__COOPDF = "../data/raw/Dados_INMET/dados_A047_D_2023-01-01_2023-12-31.csv"
PATH_PARATY = "../data/raw/Dados_INMET/dados_A619_D_2023-01-01_2023-12-31.csv"
PATH_PARAUNA = "../data/raw/Dados_INMET/dados_A027_D_2023-01-01_2023-12-31.csv"
PATH_PARINTINS = "../data/raw/Dados_INMET/dados_A123_D_2023-01-01_2023-12-31.csv"
PATH_PARNAIBA = "../data/raw/Dados_INMET/dados_A308_D_2023-01-01_2023-12-31.csv"
PATH_PARQUE_ESTADUAL_CHANDLESS = "../data/raw/Dados_INMET/dados_A102_D_2023-01-01_2023-12-31.csv"
PATH_PASSA_QUATRO = "../data/raw/Dados_INMET/dados_A529_D_2023-01-01_2023-12-31.csv"
PATH_PASSO_FUNDO = "../data/raw/Dados_INMET/dados_A839_D_2023-01-01_2023-12-31.csv"
PATH_PASSOS = "../data/raw/Dados_INMET/dados_A516_D_2023-01-01_2023-12-31.csv"
PATH_PATOS = "../data/raw/Dados_INMET/dados_A321_D_2023-01-01_2023-12-31.csv"
PATH_PATOS_DE_MINAS = "../data/raw/Dados_INMET/dados_A562_D_2023-01-01_2023-12-31.csv"
PATH_PATROCINIO = "../data/raw/Dados_INMET/dados_A523_D_2023-01-01_2023-12-31.csv"
PATH_PAULISTANA = "../data/raw/Dados_INMET/dados_A330_D_2023-01-01_2023-12-31.csv"
PATH_PEDRO_AFONSO = "../data/raw/Dados_INMET/dados_A020_D_2023-01-01_2023-12-31.csv"
PATH_PEIXE = "../data/raw/Dados_INMET/dados_A018_D_2023-01-01_2023-12-31.csv"
PATH_PETROLINA = "../data/raw/Dados_INMET/dados_A307_D_2023-01-01_2023-12-31.csv"
PATH_PIATA = "../data/raw/Dados_INMET/dados_A430_D_2023-01-01_2023-12-31.csv"
PATH_PICO_DO_COUTO = "../data/raw/Dados_INMET/dados_A610_D_2023-01-01_2023-12-31.csv"
PATH_PICOS = "../data/raw/Dados_INMET/dados_A343_D_2023-01-01_2023-12-31.csv"
PATH_PIRACICABA = "../data/raw/Dados_INMET/dados_A726_D_2023-01-01_2023-12-31.csv"
PATH_PIRANHAS = "../data/raw/Dados_INMET/dados_A371_D_2023-01-01_2023-12-31.csv"
PATH_PIRAPORA = "../data/raw/Dados_INMET/dados_A545_D_2023-01-01_2023-12-31.csv"
PATH_PIRES_DO_RIO = "../data/raw/Dados_INMET/dados_A033_D_2023-01-01_2023-12-31.csv"
PATH_PIRIPIRI = "../data/raw/Dados_INMET/dados_A335_D_2023-01-01_2023-12-31.csv"
PATH_PIUM = "../data/raw/Dados_INMET/dados_A051_D_2023-01-01_2023-12-31.csv"
PATH_PLACAS = "../data/raw/Dados_INMET/dados_A211_D_2023-01-01_2023-12-31.csv"
PATH_PLANALTO = "../data/raw/Dados_INMET/dados_A855_D_2023-01-01_2023-12-31.csv"
PATH_POCO_VERDE = "../data/raw/Dados_INMET/dados_A419_D_2023-01-01_2023-12-31.csv"
PATH_POMPEU = "../data/raw/Dados_INMET/dados_A560_D_2023-01-01_2023-12-31.csv"
PATH_PONTA_PORA = "../data/raw/Dados_INMET/dados_A703_D_2023-01-01_2023-12-31.csv"
PATH_PONTES_E_LACERDA = "../data/raw/Dados_INMET/dados_A937_D_2023-01-01_2023-12-31.csv"
PATH_PORANGATU = "../data/raw/Dados_INMET/dados_A005_D_2023-01-01_2023-12-31.csv"
PATH_PORTO_ALEGRE___JARDIM_BOTANICO = "../data/raw/Dados_INMET/dados_A801_D_2023-01-01_2023-12-31.csv"
PATH_PORTO_ALEGRE__BELEM_NOVO = "../data/raw/Dados_INMET/dados_B807_D_2023-01-01_2023-12-31.csv"
PATH_PORTO_DE_MOZ = "../data/raw/Dados_INMET/dados_A245_D_2023-01-01_2023-12-31.csv"
PATH_PORTO_ESTRELA = "../data/raw/Dados_INMET/dados_A935_D_2023-01-01_2023-12-31.csv"
PATH_PORTO_GRANDE = "../data/raw/Dados_INMET/dados_A244_D_2023-01-01_2023-12-31.csv"
PATH_PORTO_MURTINHO = "../data/raw/Dados_INMET/dados_A723_D_2023-01-01_2023-12-31.csv"
PATH_PORTO_SEGURO = "../data/raw/Dados_INMET/dados_A427_D_2023-01-01_2023-12-31.csv"
PATH_PORTO_VELHO = "../data/raw/Dados_INMET/dados_A925_D_2023-01-01_2023-12-31.csv"
PATH_PORTO_WALTER = "../data/raw/Dados_INMET/dados_A136_D_2023-01-01_2023-12-31.csv"
PATH_POSSE = "../data/raw/Dados_INMET/dados_A017_D_2023-01-01_2023-12-31.csv"
PATH_PRADOPOLIS = "../data/raw/Dados_INMET/dados_A747_D_2023-01-01_2023-12-31.csv"
PATH_PREGUICAS = "../data/raw/Dados_INMET/dados_A218_D_2023-01-01_2023-12-31.csv"
PATH_PRESIDENTE_FIGUEIREDO = "../data/raw/Dados_INMET/dados_A126_D_2023-01-01_2023-12-31.csv"
PATH_PRESIDENTE_KENNEDY = "../data/raw/Dados_INMET/dados_A622_D_2023-01-01_2023-12-31.csv"
PATH_PRESIDENTE_PRUDENTE = "../data/raw/Dados_INMET/dados_A707_D_2023-01-01_2023-12-31.csv"
PATH_PRIMAVERA_DO_LESTE = "../data/raw/Dados_INMET/dados_A923_D_2023-01-01_2023-12-31.csv"
PATH_PATY_DO_ALFERES___AVELAR = "../data/raw/Dados_INMET/dados_A637_D_2023-01-01_2023-12-31.csv"
PATH_QUARAI = "../data/raw/Dados_INMET/dados_A831_D_2023-01-01_2023-12-31.csv"
PATH_QUEIMADAS = "../data/raw/Dados_INMET/dados_A436_D_2023-01-01_2023-12-31.csv"
PATH_QUERENCIA = "../data/raw/Dados_INMET/dados_A916_D_2023-01-01_2023-12-31.csv"
PATH_QUIXADA = "../data/raw/Dados_INMET/dados_A369_D_2023-01-01_2023-12-31.csv"
PATH_QUIXERAMOBIM = "../data/raw/Dados_INMET/dados_A325_D_2023-01-01_2023-12-31.csv"
PATH_RANCHARIA = "../data/raw/Dados_INMET/dados_A718_D_2023-01-01_2023-12-31.csv"
PATH_RANCHO_QUEIMADO = "../data/raw/Dados_INMET/dados_A870_D_2023-01-01_2023-12-31.csv"
PATH_RECIFE = "../data/raw/Dados_INMET/dados_A301_D_2023-01-01_2023-12-31.csv"
PATH_REDENCAO = "../data/raw/Dados_INMET/dados_A254_D_2023-01-01_2023-12-31.csv"
PATH_REGISTRO = "../data/raw/Dados_INMET/dados_A766_D_2023-01-01_2023-12-31.csv"
PATH_REMANSO = "../data/raw/Dados_INMET/dados_A423_D_2023-01-01_2023-12-31.csv"
PATH_RESENDE = "../data/raw/Dados_INMET/dados_A609_D_2023-01-01_2023-12-31.csv"
PATH_RIBEIRA_DO_AMPARO = "../data/raw/Dados_INMET/dados_A458_D_2023-01-01_2023-12-31.csv"
PATH_RIO_BRANCO = "../data/raw/Dados_INMET/dados_A104_D_2023-01-01_2023-12-31.csv"
PATH_RIO_BRILHANTE = "../data/raw/Dados_INMET/dados_A743_D_2023-01-01_2023-12-31.csv"
PATH_RIO_CLARO = "../data/raw/Dados_INMET/dados_A626_D_2023-01-01_2023-12-31.csv"
PATH_RIO_DE_JANEIRO___FORTE_DE_COPACABANA = "../data/raw/Dados_INMET/dados_A652_D_2023-01-01_2023-12-31.csv"
PATH_RIO_DE_JANEIRO___JACAREPAGUA = "../data/raw/Dados_INMET/dados_A636_D_2023-01-01_2023-12-31.csv"
PATH_RIO_DE_JANEIRO___VILA_MILITAR = "../data/raw/Dados_INMET/dados_A621_D_2023-01-01_2023-12-31.csv"
PATH_RIO_DE_JANEIRO_MARAMBAIA = "../data/raw/Dados_INMET/dados_A602_D_2023-01-01_2023-12-31.csv"
PATH_RIO_DO_CAMPO = "../data/raw/Dados_INMET/dados_A861_D_2023-01-01_2023-12-31.csv"
PATH_RIO_GRANDE = "../data/raw/Dados_INMET/dados_A802_D_2023-01-01_2023-12-31.csv"
PATH_RIO_NEGRINHO = "../data/raw/Dados_INMET/dados_A862_D_2023-01-01_2023-12-31.csv"
PATH_RIO_PARDO = "../data/raw/Dados_INMET/dados_A813_D_2023-01-01_2023-12-31.csv"
PATH_RIO_PARDO_DE_MINAS = "../data/raw/Dados_INMET/dados_A551_D_2023-01-01_2023-12-31.csv"
PATH_RIO_SONO = "../data/raw/Dados_INMET/dados_A050_D_2023-01-01_2023-12-31.csv"
PATH_RIO_URUBU = "../data/raw/Dados_INMET/dados_A125_D_2023-01-01_2023-12-31.csv"
PATH_RIO_VERDE = "../data/raw/Dados_INMET/dados_A025_D_2023-01-01_2023-12-31.csv"
PATH_RONDON_DO_PARA = "../data/raw/Dados_INMET/dados_A214_D_2023-01-01_2023-12-31.csv"
PATH_RONDONOPOLIS = "../data/raw/Dados_INMET/dados_A907_D_2023-01-01_2023-12-31.csv"
PATH_ROSARIO_OESTE = "../data/raw/Dados_INMET/dados_A944_D_2023-01-01_2023-12-31.csv"
PATH_S_G_DA_CACHOEIRA = "../data/raw/Dados_INMET/dados_A134_D_2023-01-01_2023-12-31.csv"
PATH_S_J_DO_RIO_CLARO = "../data/raw/Dados_INMET/dados_A903_D_2023-01-01_2023-12-31.csv"
PATH_SACRAMENTO = "../data/raw/Dados_INMET/dados_A525_D_2023-01-01_2023-12-31.csv"
PATH_SALGUEIRO = "../data/raw/Dados_INMET/dados_A370_D_2023-01-01_2023-12-31.csv"
PATH_SALINAS = "../data/raw/Dados_INMET/dados_A552_D_2023-01-01_2023-12-31.csv"
PATH_SALINOPOLIS = "../data/raw/Dados_INMET/dados_A215_D_2023-01-01_2023-12-31.csv"
PATH_SALTO_DO_CEU = "../data/raw/Dados_INMET/dados_A936_D_2023-01-01_2023-12-31.csv"
PATH_SALVADOR = "../data/raw/Dados_INMET/dados_A401_D_2023-01-01_2023-12-31.csv"
PATH_SALVADOR__RADIO_FAROL = "../data/raw/Dados_INMET/dados_A456_D_2023-01-01_2023-12-31.csv"
PATH_SANTA_CRUZ = "../data/raw/Dados_INMET/dados_A367_D_2023-01-01_2023-12-31.csv"
PATH_SANTA_FE_DO_ARAGUAIA = "../data/raw/Dados_INMET/dados_A048_D_2023-01-01_2023-12-31.csv"
PATH_SANTA_MARIA = "../data/raw/Dados_INMET/dados_A803_D_2023-01-01_2023-12-31.csv"
PATH_SANTA_MARIA_DAS_BARREIRAS = "../data/raw/Dados_INMET/dados_A256_D_2023-01-01_2023-12-31.csv"
PATH_SANTA_MARIA_MADALENA = "../data/raw/Dados_INMET/dados_A630_D_2023-01-01_2023-12-31.csv"
PATH_SANTA_RITA_DE_CASSIA = "../data/raw/Dados_INMET/dados_A415_D_2023-01-01_2023-12-31.csv"
PATH_SANTA_ROSA = "../data/raw/Dados_INMET/dados_A810_D_2023-01-01_2023-12-31.csv"
PATH_SANTA_ROSA_DO_TOCANTINS = "../data/raw/Dados_INMET/dados_A052_D_2023-01-01_2023-12-31.csv"
PATH_SANTA_TERESA = "../data/raw/Dados_INMET/dados_A613_D_2023-01-01_2023-12-31.csv"
PATH_SANTANA_DO_ARAGUAIA = "../data/raw/Dados_INMET/dados_A233_D_2023-01-01_2023-12-31.csv"
PATH_SANTANA_DO_LIVRAMENTO = "../data/raw/Dados_INMET/dados_A804_D_2023-01-01_2023-12-31.csv"
PATH_SANTAREM = "../data/raw/Dados_INMET/dados_A250_D_2023-01-01_2023-12-31.csv"
PATH_SANTIAGO = "../data/raw/Dados_INMET/dados_A833_D_2023-01-01_2023-12-31.csv"
PATH_SANTO_ANTONIO_DO_LESTE = "../data/raw/Dados_INMET/dados_A931_D_2023-01-01_2023-12-31.csv"
PATH_SANTO_AUGUSTO = "../data/raw/Dados_INMET/dados_A805_D_2023-01-01_2023-12-31.csv"
PATH_SAO_BORJA = "../data/raw/Dados_INMET/dados_A830_D_2023-01-01_2023-12-31.csv"
PATH_SAO_CARLOS = "../data/raw/Dados_INMET/dados_A711_D_2023-01-01_2023-12-31.csv"
PATH_SAO_FELIX_DO_ARAGUAIA = "../data/raw/Dados_INMET/dados_A921_D_2023-01-01_2023-12-31.csv"
PATH_SAO_FELIX_DO_XINGU = "../data/raw/Dados_INMET/dados_A216_D_2023-01-01_2023-12-31.csv"
PATH_SAO_GABRIEL = "../data/raw/Dados_INMET/dados_A832_D_2023-01-01_2023-12-31.csv"
PATH_SAO_GABRIEL_DO_OESTE = "../data/raw/Dados_INMET/dados_A732_D_2023-01-01_2023-12-31.csv"
PATH_SAO_GONCALO = "../data/raw/Dados_INMET/dados_A333_D_2023-01-01_2023-12-31.csv"
PATH_SAO_JOAO_DEL_REI = "../data/raw/Dados_INMET/dados_A514_D_2023-01-01_2023-12-31.csv"
PATH_SAO_JOAO_DO_PIAUI = "../data/raw/Dados_INMET/dados_A331_D_2023-01-01_2023-12-31.csv"
PATH_SAO_JOAQUIM = "../data/raw/Dados_INMET/dados_A815_D_2023-01-01_2023-12-31.csv"
PATH_SAO_JOSE_DO_XINGU = "../data/raw/Dados_INMET/dados_A942_D_2023-01-01_2023-12-31.csv"
PATH_SAO_JOSE_DOS_AUSENTES = "../data/raw/Dados_INMET/dados_A829_D_2023-01-01_2023-12-31.csv"
PATH_SAO_LUIS = "../data/raw/Dados_INMET/dados_A203_D_2023-01-01_2023-12-31.csv"
PATH_SAO_LUIS_DO_QUITUNDE = "../data/raw/Dados_INMET/dados_A356_D_2023-01-01_2023-12-31.csv"
PATH_SAO_LUIZ_DO_PARAITINGA = "../data/raw/Dados_INMET/dados_A740_D_2023-01-01_2023-12-31.csv"
PATH_SAO_LUIZ_GONZAGA = "../data/raw/Dados_INMET/dados_A852_D_2023-01-01_2023-12-31.csv"
PATH_SAO_MATEUS = "../data/raw/Dados_INMET/dados_A616_D_2023-01-01_2023-12-31.csv"
PATH_SAO_MATEUS_DO_SUL = "../data/raw/Dados_INMET/dados_A874_D_2023-01-01_2023-12-31.csv"
PATH_SAO_MIGUEL_ARCANJO = "../data/raw/Dados_INMET/dados_A715_D_2023-01-01_2023-12-31.csv"
PATH_SAO_MIGUEL_DO_ARAGUAIA = "../data/raw/Dados_INMET/dados_A031_D_2023-01-01_2023-12-31.csv"
PATH_SAO_MIGUEL_DO_OESTE = "../data/raw/Dados_INMET/dados_A857_D_2023-01-01_2023-12-31.csv"
PATH_SAO_PAULO___INTERLAGOS = "../data/raw/Dados_INMET/dados_A771_D_2023-01-01_2023-12-31.csv"
PATH_SAO_PAULO___MIRANTE = "../data/raw/Dados_INMET/dados_A701_D_2023-01-01_2023-12-31.csv"
PATH_SAO_RAIMUNDO_NONATO = "../data/raw/Dados_INMET/dados_A345_D_2023-01-01_2023-12-31.csv"
PATH_SAO_ROMAO = "../data/raw/Dados_INMET/dados_A547_D_2023-01-01_2023-12-31.csv"
PATH_SAO_SEBASTIAO_DO_PARAISO = "../data/raw/Dados_INMET/dados_A561_D_2023-01-01_2023-12-31.csv"
PATH_SAO_SIMAO = "../data/raw/Dados_INMET/dados_A011_D_2023-01-01_2023-12-31.csv"
PATH_SAO_VICENTE_DO_SUL = "../data/raw/Dados_INMET/dados_A889_D_2023-01-01_2023-12-31.csv"
PATH_SAPEZAL = "../data/raw/Dados_INMET/dados_A911_D_2023-01-01_2023-12-31.csv"
PATH_SAQUAREMA___SAMPAIO_CORREIA = "../data/raw/Dados_INMET/dados_A667_D_2023-01-01_2023-12-31.csv"
PATH_SENHOR_DO_BONFIM = "../data/raw/Dados_INMET/dados_A428_D_2023-01-01_2023-12-31.csv"
PATH_SERAFINA_CORREA = "../data/raw/Dados_INMET/dados_A894_D_2023-01-01_2023-12-31.csv"
PATH_SEROPEDICA_ECOLOGIA_AGRICOLA = "../data/raw/Dados_INMET/dados_A601_D_2023-01-01_2023-12-31.csv"
PATH_SERRA_DOS_AIMORES = "../data/raw/Dados_INMET/dados_A522_D_2023-01-01_2023-12-31.csv"
PATH_SERRA_DOS_CARAJAS = "../data/raw/Dados_INMET/dados_A230_D_2023-01-01_2023-12-31.csv"
PATH_SERRA_NOVA_DOURADA = "../data/raw/Dados_INMET/dados_A943_D_2023-01-01_2023-12-31.csv"
PATH_SERRA_TALHADA = "../data/raw/Dados_INMET/dados_A350_D_2023-01-01_2023-12-31.csv"
PATH_SERRINHA = "../data/raw/Dados_INMET/dados_A441_D_2023-01-01_2023-12-31.csv"
PATH_SETE_LAGOAS = "../data/raw/Dados_INMET/dados_A569_D_2023-01-01_2023-12-31.csv"
PATH_SETE_QUEDAS = "../data/raw/Dados_INMET/dados_A751_D_2023-01-01_2023-12-31.csv"
PATH_SIDROLANDIA = "../data/raw/Dados_INMET/dados_A754_D_2023-01-01_2023-12-31.csv"
PATH_SILVA_JARDIM = "../data/raw/Dados_INMET/dados_A659_D_2023-01-01_2023-12-31.csv"
PATH_SILVANIA = "../data/raw/Dados_INMET/dados_A037_D_2023-01-01_2023-12-31.csv"
PATH_SINOP = "../data/raw/Dados_INMET/dados_A917_D_2023-01-01_2023-12-31.csv"
PATH_SOBRAL = "../data/raw/Dados_INMET/dados_A306_D_2023-01-01_2023-12-31.csv"
PATH_SOLEDADE = "../data/raw/Dados_INMET/dados_A837_D_2023-01-01_2023-12-31.csv"
PATH_SONORA = "../data/raw/Dados_INMET/dados_A761_D_2023-01-01_2023-12-31.csv"
PATH_SOROCABA = "../data/raw/Dados_INMET/dados_A713_D_2023-01-01_2023-12-31.csv"
PATH_SORRISO = "../data/raw/Dados_INMET/dados_A904_D_2023-01-01_2023-12-31.csv"
PATH_SOURE = "../data/raw/Dados_INMET/dados_A227_D_2023-01-01_2023-12-31.csv"
PATH_SURUBIM = "../data/raw/Dados_INMET/dados_A328_D_2023-01-01_2023-12-31.csv"
PATH_SANTA_VITORIA_DO_PALMAR___BARRA_DO_CHUI = "../data/raw/Dados_INMET/dados_A899_D_2023-01-01_2023-12-31.csv"
PATH_TANGARA_DA_SERRA = "../data/raw/Dados_INMET/dados_A902_D_2023-01-01_2023-12-31.csv"
PATH_TAUA = "../data/raw/Dados_INMET/dados_A324_D_2023-01-01_2023-12-31.csv"
PATH_TAUBATE = "../data/raw/Dados_INMET/dados_A728_D_2023-01-01_2023-12-31.csv"
PATH_TEOFILO_OTONI = "../data/raw/Dados_INMET/dados_A527_D_2023-01-01_2023-12-31.csv"
PATH_TERESINA = "../data/raw/Dados_INMET/dados_A312_D_2023-01-01_2023-12-31.csv"
PATH_TERESOPOLIS_PARQUE_NACIONAL = "../data/raw/Dados_INMET/dados_A618_D_2023-01-01_2023-12-31.csv"
PATH_TEUTONIA = "../data/raw/Dados_INMET/dados_A882_D_2023-01-01_2023-12-31.csv"
PATH_TIANGUA = "../data/raw/Dados_INMET/dados_A368_D_2023-01-01_2023-12-31.csv"
PATH_TIMOTEO = "../data/raw/Dados_INMET/dados_A511_D_2023-01-01_2023-12-31.csv"
PATH_TOME_ACU = "../data/raw/Dados_INMET/dados_A213_D_2023-01-01_2023-12-31.csv"
PATH_TORRES = "../data/raw/Dados_INMET/dados_A808_D_2023-01-01_2023-12-31.csv"
PATH_TRAMANDAI = "../data/raw/Dados_INMET/dados_A834_D_2023-01-01_2023-12-31.csv"
PATH_TRES_LAGOAS = "../data/raw/Dados_INMET/dados_A704_D_2023-01-01_2023-12-31.csv"
PATH_TRES_MARIAS = "../data/raw/Dados_INMET/dados_A528_D_2023-01-01_2023-12-31.csv"
PATH_TRES_RIOS = "../data/raw/Dados_INMET/dados_A625_D_2023-01-01_2023-12-31.csv"
PATH_TUCUMA = "../data/raw/Dados_INMET/dados_A234_D_2023-01-01_2023-12-31.csv"
PATH_TUCURUI = "../data/raw/Dados_INMET/dados_A229_D_2023-01-01_2023-12-31.csv"
PATH_TUPA = "../data/raw/Dados_INMET/dados_A768_D_2023-01-01_2023-12-31.csv"
PATH_TUPANCIRETA = "../data/raw/Dados_INMET/dados_A886_D_2023-01-01_2023-12-31.csv"
PATH_TURIACU = "../data/raw/Dados_INMET/dados_A219_D_2023-01-01_2023-12-31.csv"
PATH_UBERABA = "../data/raw/Dados_INMET/dados_A568_D_2023-01-01_2023-12-31.csv"
PATH_UBERLANDIA = "../data/raw/Dados_INMET/dados_A507_D_2023-01-01_2023-12-31.csv"
PATH_UNA = "../data/raw/Dados_INMET/dados_A437_D_2023-01-01_2023-12-31.csv"
PATH_UNAI = "../data/raw/Dados_INMET/dados_A542_D_2023-01-01_2023-12-31.csv"
PATH_URUCARA = "../data/raw/Dados_INMET/dados_A124_D_2023-01-01_2023-12-31.csv"
PATH_URUCUI = "../data/raw/Dados_INMET/dados_A346_D_2023-01-01_2023-12-31.csv"
PATH_URUGUAIANA = "../data/raw/Dados_INMET/dados_A809_D_2023-01-01_2023-12-31.csv"
PATH_URUSSANGA = "../data/raw/Dados_INMET/dados_A814_D_2023-01-01_2023-12-31.csv"
PATH_VACARIA = "../data/raw/Dados_INMET/dados_A880_D_2023-01-01_2023-12-31.csv"
PATH_VALENCA = "../data/raw/Dados_INMET/dados_A444_D_2023-01-01_2023-12-31.csv"
PATH_VALENCA_DO_PIAUI = "../data/raw/Dados_INMET/dados_A363_D_2023-01-01_2023-12-31.csv"
PATH_VALPARAISO = "../data/raw/Dados_INMET/dados_A734_D_2023-01-01_2023-12-31.csv"
PATH_VARGINHA = "../data/raw/Dados_INMET/dados_A515_D_2023-01-01_2023-12-31.csv"
PATH_VENDA_NOVA_DO_IMIGRANTE = "../data/raw/Dados_INMET/dados_A633_D_2023-01-01_2023-12-31.csv"
PATH_VENTANIA = "../data/raw/Dados_INMET/dados_A872_D_2023-01-01_2023-12-31.csv"
PATH_VICOSA = "../data/raw/Dados_INMET/dados_A510_D_2023-01-01_2023-12-31.csv"
PATH_VILA_BELA_DA_SANTISSIMA_TRINDADE = "../data/raw/Dados_INMET/dados_A922_D_2023-01-01_2023-12-31.csv"
PATH_VILA_VELHA = "../data/raw/Dados_INMET/dados_A634_D_2023-01-01_2023-12-31.csv"
PATH_VILHENA = "../data/raw/Dados_INMET/dados_A938_D_2023-01-01_2023-12-31.csv"
PATH_VITORIA = "../data/raw/Dados_INMET/dados_A612_D_2023-01-01_2023-12-31.csv"
PATH_VITORIA_DA_CONQUISTA = "../data/raw/Dados_INMET/dados_A414_D_2023-01-01_2023-12-31.csv"
PATH_XANXERE = "../data/raw/Dados_INMET/dados_A858_D_2023-01-01_2023-12-31.csv"
PATH_XINGUARA = "../data/raw/Dados_INMET/dados_A247_D_2023-01-01_2023-12-31.csv"
PATH_ZE_DOCA = "../data/raw/Dados_INMET/dados_A255_D_2023-01-01_2023-12-31.csv"

# %%
lista_total = [
    PATH_ABROLHOS,
    PATH_ACARAU,
    PATH_AFONSO_CLAUDIO,
    PATH_AGUA_BOA,
    PATH_AGUA_CLARA,
    PATH_AGUAS_EMENDADAS,
    PATH_AGUAS_VERMELHAS,
    PATH_AIMORES,
    PATH_ALEGRE,
    PATH_ALEGRETE,
    PATH_ALFREDO_CHAVES,
    PATH_ALMAS,
    PATH_ALMENARA,
    PATH_ALTA_FLORESTA,
    PATH_ALTAMIRA,
    PATH_ALTO_ARAGUAIA,
    PATH_ALTO_PARAISO_DE_GOIAS,
    PATH_ALTO_PARNAIBA,
    PATH_ALTO_TAQUARI,
    PATH_ALVORADA_DO_GURGUEIA,
    PATH_AMAMBAI,
    PATH_AMARGOSA,
    PATH_ANGICAL_DO_PIAUI,
    PATH_ANGRA_DOS_REIS,
    PATH_APIACAS,
    PATH_APODI,
    PATH_APUI,
    PATH_AQUIDAUANA,
    PATH_ARACAJU,
    PATH_ARACUAI,
    PATH_ARAGARCAS,
    PATH_ARAGUACU,
    PATH_ARAGUAINA,
    PATH_ARAGUATINS,
    PATH_ARAPIRACA,
    PATH_ARARANGUA,
    PATH_ARAXA,
    PATH_ARCO_VERDE,
    PATH_AREIA,
    PATH_ARIQUEMES,
    PATH_ARIRANHA,
    PATH_ARRAIAL_DO_CABO,
    PATH_AUTAZES,
    PATH_AVARE,
    PATH_BACABAL,
    PATH_BAGE,
    PATH_BAIXA_GRANDE_DO_RIBEIRO,
    PATH_BALSAS,
    PATH_BAMBUI,
    PATH_BARBACENA,
    PATH_BARBALHA,
    PATH_BARCELOS,
    PATH_BARRA,
    PATH_BARRA_BONITA,
    PATH_BARRA_DO_CORDA,
    PATH_BARRA_DO_TURVO,
    PATH_BARREIRAS,
    PATH_BARRETOS,
    PATH_BARUERI,
    PATH_BATAGUASSU,
    PATH_BAURU,
    PATH_BEBEDOURO,
    PATH_BELEM,
    PATH_BELMONTE,
    PATH_BELO_HORIZONTE__PAMPLHA,
    PATH_BELO_HORIZONTE___CERCADINHO,
    PATH_BENTO_GONCALVES,
    PATH_BERTIOGA,
    PATH_BOA_VISTA,
    PATH_BOCA_DO_ACRE,
    PATH_BOM_JARDIM_DA_SERRA___MORRO_DA_IGREJA,
    PATH_BOM_JESUS_DA_LAPA,
    PATH_BOM_JESUS_DO_PIAUI,
    PATH_BRAGANCA,
    PATH_BRAGANCA_PAULISTA,
    PATH_BRASILIA,
    PATH_BRASNORTE__NOVO_MUNDO,
    PATH_BRAZLANDIA,
    PATH_BREJO_GRANDE,
    PATH_BREVES,
    PATH_BRUMADO,
    PATH_BURITICUPU,
    PATH_BURITIRAMA,
    PATH_BURITIS,
    PATH_CABACEIRAS,
    PATH_CABROBO,
    PATH_CACADOR,
    PATH_CACAPAVA_DO_SUL,
    PATH_CACHOEIRA_PAULISTA,
    PATH_CACOAL,
    PATH_CAIAPONIA,
    PATH_CAICO,
    PATH_CALCANHAR,
    PATH_CALDAS,
    PATH_CAMAQUA,
    PATH_CAMARATUBA,
    PATH_CAMBARA_DO_SUL,
    PATH_CAMBUCI,
    PATH_CAMETA,
    PATH_CAMPINA_DA_LAGOA,
    PATH_CAMPINA_GRANDE,
    PATH_CAMPINA_VERDE,
    PATH_CAMPO_BOM,
    PATH_CAMPO_GRANDE,
    PATH_CAMPO_MAIOR,
    PATH_CAMPO_NOVO_DOS_PARECIS,
    PATH_CAMPO_VERDE,
    PATH_CAMPOS_DO_JORDAO,
    PATH_CAMPOS_DOS_GOYTACAZES,
    PATH_CAMPOS_DOS_GOYTACAZES___SAO_TOME,
    PATH_CAMPOS_LINDOS,
    PATH_CAMPOS_NOVOS,
    PATH_CAMPOS_SALES,
    PATH_CANELA,
    PATH_CANGUCU,
    PATH_CANTO_DO_BURITI,
    PATH_CAPAO_DO_LEAO_PELOTAS,
    PATH_CAPELINHA,
    PATH_CAPITAO_POCO,
    PATH_CARACOL,
    PATH_CARATINGA,
    PATH_CARAVELAS,
    PATH_CARLINDA,
    PATH_CARMO,
    PATH_CAROLINA,
    PATH_CARUARU,
    PATH_CASA_BRANCA,
    PATH_CASSILANDIA,
    PATH_CASTANHAL,
    PATH_CASTELO_DO_PIAUI,
    PATH_CASTRO,
    PATH_CATALAO,
    PATH_CAXIAS,
    PATH_CHAPADA_GAUCHA,
    PATH_CHAPADAO_DO_SUL,
    PATH_CHAPADINHA,
    PATH_CHAPECO,
    PATH_CIDADE_GAUCHA,
    PATH_CLEVELANDIA,
    PATH_COARI,
    PATH_COLINAS,
    PATH_COLINAS_DO_TOCANTINS,
    PATH_COLOMBO,
    PATH_COMODORO,
    PATH_CONCEICAO_DAS_ALAGOAS,
    PATH_CONCEICAO_DO_ARAGUAIA,
    PATH_CONDE,
    PATH_CORONEL_PACHECO,
    PATH_CORRENTE,
    PATH_CORRENTINA,
    PATH_CORUMBA,
    PATH_CORURIPE,
    PATH_COSTA_RICA,
    PATH_COTRIGUACU,
    PATH_COXIM,
    PATH_CRATEUS,
    PATH_CRISTALINA,
    PATH_CRISTALINA_FAZENDA_SANTA_MONICA,
    PATH_CRUZ_ALTA,
    PATH_CRUZ_DAS_ALMAS,
    PATH_CRUZEIRO_DO_SUL,
    PATH_CUIABA,
    PATH_CURACA,
    PATH_ERECHIM,
    PATH_ESPINOSA,
    PATH_ESTREITO,
    PATH_EUCLIDES_DA_CUNHA,
    PATH_FAROL_de_SANTANA,
    PATH_FEIJO,
    PATH_FEIRA_DE_SANTANA,
    PATH_FLORESTA,
    PATH_FLORESTAL,
    PATH_FLORIANO,
    PATH_FLORIANOPOLIS,
    PATH_FORMIGA,
    PATH_FORMOSA_DO_RIO_PRETO,
    PATH_FORMOSO_DO_ARAGUAIA,
    PATH_FORTALEZA,
    PATH_FOZ_DO_IGUACU,
    PATH_FRANCA,
    PATH_FREDERICO_WESTPHALEN,
    PATH_GAMA__PONT_ALTA,
    PATH_GARANHUNS,
    PATH_GAUCHA_DO_NORTE,
    PATH_GENERAL_CARNEIRO,
    PATH_GILBUES,
    PATH_GOIANESIA,
    PATH_GOIANIA,
    PATH_GOIAS,
    PATH_GOIOERE,
    PATH_GOVERNADOR_VALADARES,
    PATH_GRAJAU,
    PATH_GUANAMBI,
    PATH_GUANHAES,
    PATH_GUARAMIRANGA,
    PATH_GUARANTA_DO_NORTE,
    PATH_GUARDA_MOR,
    PATH_GUIRATINGA,
    PATH_GURUPI,
    PATH_HUMAITA,
    PATH_IBIMIRIM,
    PATH_IBIRITE__ROLAMOCA,
    PATH_IBIRUBA,
    PATH_IBITINGA,
    PATH_IBOTIRAMA,
    PATH_ICARAIMA,
    PATH_IGUAPE,
    PATH_IGUATU,
    PATH_ILHEUS,
    PATH_IMPERATRIZ,
    PATH_INACIO_MARTINS,
    PATH_INDAIAL,
    PATH_IPANGUACU,
    PATH_IPIAU,
    PATH_IPORA,
    PATH_IRECE,
    PATH_ITABAIANA,
    PATH_ITABAIANINHA,
    PATH_ITABERABA,
    PATH_ITACOATIARA,
    PATH_ITAITUBA,
    PATH_ITAJAI,
    PATH_ITAMARAJU,
    PATH_ITAOBIM,
    PATH_ITAPACI,
    PATH_ITAPETINGA,
    PATH_ITAPEVA,
    PATH_ITAPIPOCA,
    PATH_ITAPIRA,
    PATH_ITAPOA,
    PATH_ITAPORANGA,
    PATH_ITAQUIRAI,
    PATH_ITAUBAL,
    PATH_ITIQUIRA,
    PATH_ITIRUCU,
    PATH_ITUIUTABA,
    PATH_ITUMBIARA,
    PATH_ITUPORANGA,
    PATH_ITUVERAVA,
    PATH_IVAI,
    PATH_IVINHEMA,
    PATH_JACOBINA,
    PATH_JAGUARAO,
    PATH_JAGUARIBE,
    PATH_JAGUARUANA,
    PATH_JALES,
    PATH_JANUARIA,
    PATH_JAPIRA,
    PATH_JARDIM,
    PATH_JATAI,
    PATH_JEREMOABO,
    PATH_JOACABA,
    PATH_JOAO_PESSOA,
    PATH_JOAO_PINHEIRO,
    PATH_JOAQUIM_TAVORA,
    PATH_JOSE_BONIFACIO,
    PATH_JUARA,
    PATH_JUINA,
    PATH_JUTI,
    PATH_LABREA,
    PATH_LAGES,
    PATH_LAGOA_DA_CONFUSAO,
    PATH_LAGOA_VERMELHA,
    PATH_LARANJEIRAS_DO_SUL,
    PATH_LENCOIS,
    PATH_LINHARES,
    PATH_LINS,
    PATH_LUIZ_EDUARDO_MAGALHAES,
    PATH_LUZIANIA,
    PATH_LAGUNA___FAROL_DE_SANTA_MARTA,
    PATH_MACAE,
    PATH_MACAJUBA,
    PATH_MACAPA,
    PATH_MACAU,
    PATH_MACEIO,
    PATH_MACHADO,
    PATH_MAJOR_VIEIRA,
    PATH_MAL_CANDIDO_RONDON,
    PATH_MANACAPURU,
    PATH_MANAUS,
    PATH_MANHUACU,
    PATH_MANICORE,
    PATH_MANTENA,
    PATH_MARABA,
    PATH_MARACAJU,
    PATH_MARAU,
    PATH_MARECHAL_THAUMATURGO,
    PATH_MARIA_DA_FE,
    PATH_MARIANOPOLIS_DO_TO,
    PATH_MARILANDIA,
    PATH_MARILIA,
    PATH_MARINGA,
    PATH_MATEIROS,
    PATH_MAUES,
    PATH_MEDICILANDIA,
    PATH_MINA_DO_PALITO,
    PATH_MINEIROS,
    PATH_MIRANDA,
    PATH_MOCAMBINHO,
    PATH_MONTALVANIA,
    PATH_MONTE_ALEGRE,
    PATH_MONTE_ALEGRE_DE_GOIAS,
    PATH_MONTE_VERDE,
    PATH_MONTEIRO,
    PATH_MONTES_CLAROS,
    PATH_MORADA_NOVA,
    PATH_MORRETES,
    PATH_MORRINHOS,
    PATH_MOSSORO,
    PATH_MOSTARDAS,
    PATH_MURIAE,
    PATH_NATAL,
    PATH_NHUMIRIM,
    PATH_NITEROI,
    PATH_NOSSA_SENHORA_DA_GLORIA,
    PATH_NOVA_FATIMA,
    PATH_NOVA_FRIBURGO___SALINAS,
    PATH_NOVA_MARINGA,
    PATH_NOVA_PORTEIRINHA__JANABA,
    PATH_NOVA_TEBAS,
    PATH_NOVA_UBIRATA,
    PATH_NOVO_ARIPUANA,
    PATH_NOVO_HORIZONTE,
    PATH_NOVO_REPARTIMENTO,
    PATH_OBIDOS,
    PATH_OEIRAS,
    PATH_OIAPOQUE,
    PATH_OLIVEIRA,
    PATH_OURICURI,
    PATH_OURINHOS,
    PATH_OURO_BRANCO,
    PATH_PACAJA,
    PATH_PALMARES,
    PATH_PALMAS,
    PATH_PALMEIRA_DAS_MISSOES,
    PATH_PALMEIRA_DOS_INDIOS,
    PATH_PAO_DE_ACUCAR,
    PATH_PARACATU,
    PATH_PARAGOMINAS,
    PATH_PARANA,
    PATH_PARANAIBA,
    PATH_PARANAPOEMA,
    PATH_PARANATINGA,
    PATH_PARANOA__COOPDF,
    PATH_PARATY,
    PATH_PARAUNA,
    PATH_PARINTINS,
    PATH_PARNAIBA,
    PATH_PARQUE_ESTADUAL_CHANDLESS,
    PATH_PASSA_QUATRO,
    PATH_PASSO_FUNDO,
    PATH_PASSOS,
    PATH_PATOS,
    PATH_PATOS_DE_MINAS,
    PATH_PATROCINIO,
    PATH_PAULISTANA,
    PATH_PEDRO_AFONSO,
    PATH_PEIXE,
    PATH_PETROLINA,
    PATH_PIATA,
    PATH_PICO_DO_COUTO,
    PATH_PICOS,
    PATH_PIRACICABA,
    PATH_PIRANHAS,
    PATH_PIRAPORA,
    PATH_PIRES_DO_RIO,
    PATH_PIRIPIRI,
    PATH_PIUM,
    PATH_PLACAS,
    PATH_PLANALTO,
    PATH_POCO_VERDE,
    PATH_POMPEU,
    PATH_PONTA_PORA,
    PATH_PONTES_E_LACERDA,
    PATH_PORANGATU,
    PATH_PORTO_ALEGRE___JARDIM_BOTANICO,
    PATH_PORTO_ALEGRE__BELEM_NOVO,
    PATH_PORTO_DE_MOZ,
    PATH_PORTO_ESTRELA,
    PATH_PORTO_GRANDE,
    PATH_PORTO_MURTINHO,
    PATH_PORTO_SEGURO,
    PATH_PORTO_VELHO,
    PATH_PORTO_WALTER,
    PATH_POSSE,
    PATH_PRADOPOLIS,
    PATH_PREGUICAS,
    PATH_PRESIDENTE_FIGUEIREDO,
    PATH_PRESIDENTE_KENNEDY,
    PATH_PRESIDENTE_PRUDENTE,
    PATH_PRIMAVERA_DO_LESTE,
    PATH_PATY_DO_ALFERES___AVELAR,
    PATH_QUARAI,
    PATH_QUEIMADAS,
    PATH_QUERENCIA,
    PATH_QUIXADA,
    PATH_QUIXERAMOBIM,
    PATH_RANCHARIA,
    PATH_RANCHO_QUEIMADO,
    PATH_RECIFE,
    PATH_REDENCAO,
    PATH_REGISTRO,
    PATH_REMANSO,
    PATH_RESENDE,
    PATH_RIBEIRA_DO_AMPARO,
    PATH_RIO_BRANCO,
    PATH_RIO_BRILHANTE,
    PATH_RIO_CLARO,
    PATH_RIO_DE_JANEIRO___FORTE_DE_COPACABANA,
    PATH_RIO_DE_JANEIRO___JACAREPAGUA,
    PATH_RIO_DE_JANEIRO___VILA_MILITAR,
    PATH_RIO_DE_JANEIRO_MARAMBAIA,
    PATH_RIO_DO_CAMPO,
    PATH_RIO_GRANDE,
    PATH_RIO_NEGRINHO,
    PATH_RIO_PARDO,
    PATH_RIO_PARDO_DE_MINAS,
    PATH_RIO_SONO,
    PATH_RIO_URUBU,
    PATH_RIO_VERDE,
    PATH_RONDON_DO_PARA,
    PATH_RONDONOPOLIS,
    PATH_ROSARIO_OESTE,
    PATH_S_G_DA_CACHOEIRA,
    PATH_S_J_DO_RIO_CLARO,
    PATH_SACRAMENTO,
    PATH_SALGUEIRO,
    PATH_SALINAS,
    PATH_SALINOPOLIS,
    PATH_SALTO_DO_CEU,
    PATH_SALVADOR,
    PATH_SALVADOR__RADIO_FAROL,
    PATH_SANTA_CRUZ,
    PATH_SANTA_FE_DO_ARAGUAIA,
    PATH_SANTA_MARIA,
    PATH_SANTA_MARIA_DAS_BARREIRAS,
    PATH_SANTA_MARIA_MADALENA,
    PATH_SANTA_RITA_DE_CASSIA,
    PATH_SANTA_ROSA,
    PATH_SANTA_ROSA_DO_TOCANTINS,
    PATH_SANTA_TERESA,
    PATH_SANTANA_DO_ARAGUAIA,
    PATH_SANTANA_DO_LIVRAMENTO,
    PATH_SANTAREM,
    PATH_SANTIAGO,
    PATH_SANTO_ANTONIO_DO_LESTE,
    PATH_SANTO_AUGUSTO,
    PATH_SAO_BORJA,
    PATH_SAO_CARLOS,
    PATH_SAO_FELIX_DO_ARAGUAIA,
    PATH_SAO_FELIX_DO_XINGU,
    PATH_SAO_GABRIEL,
    PATH_SAO_GABRIEL_DO_OESTE,
    PATH_SAO_GONCALO,
    PATH_SAO_JOAO_DEL_REI,
    PATH_SAO_JOAO_DO_PIAUI,
    PATH_SAO_JOAQUIM,
    PATH_SAO_JOSE_DO_XINGU,
    PATH_SAO_JOSE_DOS_AUSENTES,
    PATH_SAO_LUIS,
    PATH_SAO_LUIS_DO_QUITUNDE,
    PATH_SAO_LUIZ_DO_PARAITINGA,
    PATH_SAO_LUIZ_GONZAGA,
    PATH_SAO_MATEUS,
    PATH_SAO_MATEUS_DO_SUL,
    PATH_SAO_MIGUEL_ARCANJO,
    PATH_SAO_MIGUEL_DO_ARAGUAIA,
    PATH_SAO_MIGUEL_DO_OESTE,
    PATH_SAO_PAULO___INTERLAGOS,
    PATH_SAO_PAULO___MIRANTE,
    PATH_SAO_RAIMUNDO_NONATO,
    PATH_SAO_ROMAO,
    PATH_SAO_SEBASTIAO_DO_PARAISO,
    PATH_SAO_SIMAO,
    PATH_SAO_VICENTE_DO_SUL,
    PATH_SAPEZAL,
    PATH_SAQUAREMA___SAMPAIO_CORREIA,
    PATH_SENHOR_DO_BONFIM,
    PATH_SERAFINA_CORREA,
    PATH_SEROPEDICA_ECOLOGIA_AGRICOLA,
    PATH_SERRA_DOS_AIMORES,
    PATH_SERRA_DOS_CARAJAS,
    PATH_SERRA_NOVA_DOURADA,
    PATH_SERRA_TALHADA,
    PATH_SERRINHA,
    PATH_SETE_LAGOAS,
    PATH_SETE_QUEDAS,
    PATH_SIDROLANDIA,
    PATH_SILVA_JARDIM,
    PATH_SILVANIA,
    PATH_SINOP,
    PATH_SOBRAL,
    PATH_SOLEDADE,
    PATH_SONORA,
    PATH_SOROCABA,
    PATH_SORRISO,
    PATH_SOURE,
    PATH_SURUBIM,
    PATH_SANTA_VITORIA_DO_PALMAR___BARRA_DO_CHUI,
    PATH_TANGARA_DA_SERRA,
    PATH_TAUA,
    PATH_TAUBATE,
    PATH_TEOFILO_OTONI,
    PATH_TERESINA,
    PATH_TERESOPOLIS_PARQUE_NACIONAL,
    PATH_TEUTONIA,
    PATH_TIANGUA,
    PATH_TIMOTEO,
    PATH_TOME_ACU,
    PATH_TORRES,
    PATH_TRAMANDAI,
    PATH_TRES_LAGOAS,
    PATH_TRES_MARIAS,
    PATH_TRES_RIOS,
    PATH_TUCUMA,
    PATH_TUCURUI,
    PATH_TUPA,
    PATH_TUPANCIRETA,
    PATH_TURIACU,
    PATH_UBERABA,
    PATH_UBERLANDIA,
    PATH_UNA,
    PATH_UNAI,
    PATH_URUCARA,
    PATH_URUCUI,
    PATH_URUGUAIANA,
    PATH_URUSSANGA,
    PATH_VACARIA,
    PATH_VALENCA,
    PATH_VALENCA_DO_PIAUI,
    PATH_VALPARAISO,
    PATH_VARGINHA,
    PATH_VENDA_NOVA_DO_IMIGRANTE,
    PATH_VENTANIA,
    PATH_VICOSA,
    PATH_VILA_BELA_DA_SANTISSIMA_TRINDADE,
    PATH_VILA_VELHA,
    PATH_VILHENA,
    PATH_VITORIA,
    PATH_VITORIA_DA_CONQUISTA,
    PATH_XANXERE,
    PATH_XINGUARA,
    PATH_ZE_DOCA,
]

# %%
df = pd.read_csv(PATH_ZE_DOCA, delimiter=';', parse_dates=['Data Medicao'])

# %%
print(df)
# Out:
#     Data Medicao PRECIPITACAO TOTAL, DIARIO (AUT)(mm)  \
# 0     2023-01-01                                  3,6
# 1     2023-01-02                                  4,6
# 2     2023-01-03                                  9,6
# 3     2023-01-04                                  8,8
# 4     2023-01-05                                    0
# ..           ...                                  ...
# 360   2023-12-27                                  8,2
# 361   2023-12-28                                  4,4
# 362   2023-12-29                                    3
# 363   2023-12-30                                    0
# 364   2023-12-31                                    4
#
#     PRESSAO ATMOSFERICA MEDIA DIARIA (AUT)(mB)  \
# 0                                    1005,1625
# 1                                       1005,4
# 2                                  1005,329167
# 3                                    1005,4875
# 4                                  1005,721739
# ...

# %%
import os
import csv

folder_path = '../data/raw/Dados_INMET/'

"""
# Iterate through all files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".csv"):
        file_path = os.path.join(folder_path, filename)

        # Read the content of the CSV file
        with open(file_path, 'r') as file:
            lines = file.readlines()

        # Remove the first ten lines
        new_lines = lines[10:]

        # Write the modified content back to the same file
        with open(file_path, 'w', newline='') as file:
            file.writelines(new_lines)

print("Done! Removed the first ten lines from all CSV files in the folder.")
"""
# Out:
# '\n# Iterate through all files in the folder\nfor filename in os.listdir(folder_path):\n    if filename.endswith(".csv"):\n        file_path = os.path.join(folder_path, filename)\n\n        # Read the content of the CSV file\n        with open(file_path, \'r\') as file:\n            lines = file.readlines()\n\n        # Remove the first ten lines\n        new_lines = lines[10:]\n\n        # Write the modified content back to the same file\n        with open(file_path, \'w\', newline=\'\') as file:\n            file.writelines(new_lines)\n\nprint("Done! Removed the first ten lines from all CSV files in the folder.")\n'

# %%
print(df['TEMPERATURA MEDIA, DIARIA (AUT)(°C)'])
# Out:
# 0        26,8875
# 1        26,3125
# 2           25,8
# 3      26,929167
# 4      28,013043
#          ...
# 360          NaN
# 361        26,55
# 362    29,252174
# 363    28,034783
# 364     26,36087
# Name: TEMPERATURA MEDIA, DIARIA (AUT)(°C), Length: 365, dtype: object

# %%
lista_total_strings = [
    "ABROLHOS",
    "ACARAU",
    "AFONSO_CLAUDIO",
    "AGUA_BOA",
    "AGUA_CLARA",
    "AGUAS_EMENDADAS",
    "AGUAS_VERMELHAS",
    "AIMORES",
    "ALEGRE",
    "ALEGRETE",
    "ALFREDO_CHAVES",
    "ALMAS",
    "ALMENARA",
    "ALTA_FLORESTA",
    "ALTAMIRA",
    "ALTO_ARAGUAIA",
    "ALTO_PARAISO_DE_GOIAS",
    "ALTO_PARNAIBA",
    "ALTO_TAQUARI",
    "ALVORADA_DO_GURGUEIA",
    "AMAMBAI",
    "AMARGOSA",
    "ANGICAL_DO_PIAUI",
    "ANGRA_DOS_REIS",
    "APIACAS",
    "APODI",
    "APUI",
    "AQUIDAUANA",
    "ARACAJU",
    "ARACUAI",
    "ARAGARCAS",
    "ARAGUACU",
    "ARAGUAINA",
    "ARAGUATINS",
    "ARAPIRACA",
    "ARARANGUA",
    "ARAXA",
    "ARCO_VERDE",
    "AREIA",
    "ARIQUEMES",
    "ARIRANHA",
    "ARRAIAL_DO_CABO",
    "AUTAZES",
    "AVARE",
    "BACABAL",
    "BAGE",
    "BAIXA_GRANDE_DO_RIBEIRO",
    "BALSAS",
    "BAMBUI",
    "BARBACENA",
    "BARBALHA",
    "BARCELOS",
    "BARRA",
    "BARRA_BONITA",
    "BARRA_DO_CORDA",
    "BARRA_DO_TURVO",
    "BARREIRAS",
    "BARRETOS",
    "BARUERI",
    "BATAGUASSU",
    "BAURU",
    "BEBEDOURO",
    "BELEM",
    "BELMONTE",
    "BELO_HORIZONTE__PAMPLHA",
    "BELO_HORIZONTE___CERCADINHO",
    "BENTO_GONCALVES",
    "BERTIOGA",
    "BOA_VISTA",
    "BOCA_DO_ACRE",
    "BOM_JARDIM_DA_SERRA___MORRO_DA_IGREJA",
    "BOM_JESUS_DA_LAPA",
    "BOM_JESUS_DO_PIAUI",
    "BRAGANCA",
    "BRAGANCA_PAULISTA",
    "BRASILIA",
    "BRASNORTE__NOVO_MUNDO",
    "BRAZLANDIA",
    "BREJO_GRANDE",
    "BREVES",
    "BRUMADO",
    "BURITICUPU",
    "BURITIRAMA",
    "BURITIS",
    "CABACEIRAS",
    "CABROBO",
    "CACADOR",
    "CACAPAVA_DO_SUL",
    "CACHOEIRA_PAULISTA",
    "CACOAL",
    "CAIAPONIA",
    "CAICO",
    "CALCANHAR",
    "CALDAS",
    "CAMAQUA",
    "CAMARATUBA",
    "CAMBARA_DO_SUL",
    "CAMBUCI",
    "CAMETA",
    "CAMPINA_DA_LAGOA",
    "CAMPINA_GRANDE",
    "CAMPINA_VERDE",
    "CAMPO_BOM",
    "CAMPO_GRANDE",
    "CAMPO_MAIOR",
    "CAMPO_NOVO_DOS_PARECIS",
    "CAMPO_VERDE",
    "CAMPOS_DO_JORDAO",
    "CAMPOS_DOS_GOYTACAZES",
    "CAMPOS_DOS_GOYTACAZES___SAO_TOME",
    "CAMPOS_LINDOS",
    "CAMPOS_NOVOS",
    "CAMPOS_SALES",
    "CANELA",
    "CANGUCU",
    "CANTO_DO_BURITI",
    "CAPAO_DO_LEAO_PELOTAS",
    "CAPELINHA",
    "CAPITAO_POCO",
    "CARACOL",
    "CARATINGA",
    "CARAVELAS",
    "CARLINDA",
    "CARMO",
    "CAROLINA",
    "CARUARU",
    "CASA_BRANCA",
    "CASSILANDIA",
    "CASTANHAL",
    "CASTELO_DO_PIAUI",
    "CASTRO",
    "CATALAO",
    "CAXIAS",
    "CHAPADA_GAUCHA",
    "CHAPADAO_DO_SUL",
    "CHAPADINHA",
    "CHAPECO",
    "CIDADE_GAUCHA",
    "CLEVELANDIA",
    "COARI",
    "COLINAS",
    "COLINAS_DO_TOCANTINS",
    "COLOMBO",
    "COMODORO",
    "CONCEICAO_DAS_ALAGOAS",
    "CONCEICAO_DO_ARAGUAIA",
    "CONDE",
    "CORONEL_PACHECO",
    "CORRENTE",
    "CORRENTINA",
    "CORUMBA",
    "CORURIPE",
    "COSTA_RICA",
    "COTRIGUACU",
    "COXIM",
    "CRATEUS",
    "CRISTALINA",
    "CRISTALINA_FAZENDA_SANTA_MONICA",
    "CRUZ_ALTA",
    "CRUZ_DAS_ALMAS",
    "CRUZEIRO_DO_SUL",
    "CUIABA",
    "CURACA",
    "ERECHIM",
    "ESPINOSA",
    "ESTREITO",
    "EUCLIDES_DA_CUNHA",
    "FAROL_de_SANTANA",
    "FEIJO",
    "FEIRA_DE_SANTANA",
    "FLORESTA",
    "FLORESTAL",
    "FLORIANO",
    "FLORIANOPOLIS",
    "FORMIGA",
    "FORMOSA_DO_RIO_PRETO",
    "FORMOSO_DO_ARAGUAIA",
    "FORTALEZA",
    "FOZ_DO_IGUACU",
    "FRANCA",
    "FREDERICO_WESTPHALEN",
    "GAMA__PONT_ALTA",
    "GARANHUNS",
    "GAUCHA_DO_NORTE",
    "GENERAL_CARNEIRO",
    "GILBUES",
    "GOIANESIA",
    "GOIANIA",
    "GOIAS",
    "GOIOERE",
    "GOVERNADOR_VALADARES",
    "GRAJAU",
    "GUANAMBI",
    "GUANHAES",
    "GUARAMIRANGA",
    "GUARANTA_DO_NORTE",
    "GUARDA_MOR",
    "GUIRATINGA",
    "GURUPI",
    "HUMAITA",
    "IBIMIRIM",
    "IBIRITE__ROLAMOCA",
    "IBIRUBA",
    "IBITINGA",
    "IBOTIRAMA",
    "ICARAIMA",
    "IGUAPE",
    "IGUATU",
    "ILHEUS",
    "IMPERATRIZ",
    "INACIO_MARTINS",
    "INDAIAL",
    "IPANGUACU",
    "IPIAU",
    "IPORA",
    "IRECE",
    "ITABAIANA",
    "ITABAIANINHA",
    "ITABERABA",
    "ITACOATIARA",
    "ITAITUBA",
    "ITAJAI",
    "ITAMARAJU",
    "ITAOBIM",
    "ITAPACI",
    "ITAPETINGA",
    "ITAPEVA",
    "ITAPIPOCA",
    "ITAPIRA",
    "ITAPOA",
    "ITAPORANGA",
    "ITAQUIRAI",
    "ITAUBAL",
    "ITIQUIRA",
    "ITIRUCU",
    "ITUIUTABA",
    "ITUMBIARA",
    "ITUPORANGA",
    "ITUVERAVA",
    "IVAI",
    "IVINHEMA",
    "JACOBINA",
    "JAGUARAO",
    "JAGUARIBE",
    "JAGUARUANA",
    "JALES",
    "JANUARIA",
    "JAPIRA",
    "JARDIM",
    "JATAI",
    "JEREMOABO",
    "JOACABA",
    "JOAO_PESSOA",
    "JOAO_PINHEIRO",
    "JOAQUIM_TAVORA",
    "JOSE_BONIFACIO",
    "JUARA",
    "JUINA",
    "JUTI",
    "LABREA",
    "LAGES",
    "LAGOA_DA_CONFUSAO",
    "LAGOA_VERMELHA",
    "LARANJEIRAS_DO_SUL",
    "LENCOIS",
    "LINHARES",
    "LINS",
    "LUIZ_EDUARDO_MAGALHAES",
    "LUZIANIA",
    "LAGUNA___FAROL_DE_SANTA_MARTA",
    "MACAE",
    "MACAJUBA",
    "MACAPA",
    "MACAU",
    "MACEIO",
    "MACHADO",
    "MAJOR_VIEIRA",
    "MAL_CANDIDO_RONDON",
    "MANACAPURU",
    "MANAUS",
    "MANHUACU",
    "MANICORE",
    "MANTENA",
    "MARABA",
    "MARACAJU",
    "MARAU",
    "MARECHAL_THAUMATURGO",
    "MARIA_DA_FE",
    "MARIANOPOLIS_DO_TO",
    "MARILANDIA",
    "MARILIA",
    "MARINGA",
    "MATEIROS",
    "MAUES",
    "MEDICILANDIA",
    "MINA_DO_PALITO",
    "MINEIROS",
    "MIRANDA",
    "MOCAMBINHO",
    "MONTALVANIA",
    "MONTE_ALEGRE",
    "MONTE_ALEGRE_DE_GOIAS",
    "MONTE_VERDE",
    "MONTEIRO",
    "MONTES_CLAROS",
    "MORADA_NOVA",
    "MORRETES",
    "MORRINHOS",
    "MOSSORO",
    "MOSTARDAS",
    "MURIAE",
    "NATAL",
    "NHUMIRIM",
    "NITEROI",
    "NOSSA_SENHORA_DA_GLORIA",
    "NOVA_FATIMA",
    "NOVA_FRIBURGO___SALINAS",
    "NOVA_MARINGA",
    "NOVA_PORTEIRINHA__JANABA",
    "NOVA_TEBAS",
    "NOVA_UBIRATA",
    "NOVO_ARIPUANA",
    "NOVO_HORIZONTE",
    "NOVO_REPARTIMENTO",
    "OBIDOS",
    "OEIRAS",
    "OIAPOQUE",
    "OLIVEIRA",
    "OURICURI",
    "OURINHOS",
    "OURO_BRANCO",
    "PACAJA",
    "PALMARES",
    "PALMAS",
    "PALMEIRA_DAS_MISSOES",
    "PALMEIRA_DOS_INDIOS",
    "PAO_DE_ACUCAR",
    "PARACATU",
    "PARAGOMINAS",
    "PARANA",
    "PARANAIBA",
    "PARANAPOEMA",
    "PARANATINGA",
    "PARANOA__COOPDF",
    "PARATY",
    "PARAUNA",
    "PARINTINS",
    "PARNAIBA",
    "PARQUE_ESTADUAL_CHANDLESS",
    "PASSA_QUATRO",
    "PASSO_FUNDO",
    "PASSOS",
    "PATOS",
    "PATOS_DE_MINAS",
    "PATROCINIO",
    "PAULISTANA",
    "PEDRO_AFONSO",
    "PEIXE",
    "PETROLINA",
    "PIATA",
    "PICO_DO_COUTO",
    "PICOS",
    "PIRACICABA",
    "PIRANHAS",
    "PIRAPORA",
    "PIRES_DO_RIO",
    "PIRIPIRI",
    "PIUM",
    "PLACAS",
    "PLANALTO",
    "POCO_VERDE",
    "POMPEU",
    "PONTA_PORA",
    "PONTES_E_LACERDA",
    "PORANGATU",
    "PORTO_ALEGRE___JARDIM_BOTANICO",
    "PORTO_ALEGRE__BELEM_NOVO",
    "PORTO_DE_MOZ",
    "PORTO_ESTRELA",
    "PORTO_GRANDE",
    "PORTO_MURTINHO",
    "PORTO_SEGURO",
    "PORTO_VELHO",
    "PORTO_WALTER",
    "POSSE",
    "PRADOPOLIS",
    "PREGUICAS",
    "PRESIDENTE_FIGUEIREDO",
    "PRESIDENTE_KENNEDY",
    "PRESIDENTE_PRUDENTE",
    "PRIMAVERA_DO_LESTE",
    "PATY_DO_ALFERES___AVELAR",
    "QUARAI",
    "QUEIMADAS",
    "QUERENCIA",
    "QUIXADA",
    "QUIXERAMOBIM",
    "RANCHARIA",
    "RANCHO_QUEIMADO",
    "RECIFE",
    "REDENCAO",
    "REGISTRO",
    "REMANSO",
    "RESENDE",
    "RIBEIRA_DO_AMPARO",
    "RIO_BRANCO",
    "RIO_BRILHANTE",
    "RIO_CLARO",
    "RIO_DE_JANEIRO___FORTE_DE_COPACABANA",
    "RIO_DE_JANEIRO___JACAREPAGUA",
    "RIO_DE_JANEIRO___VILA_MILITAR",
    "RIO_DE_JANEIRO_MARAMBAIA",
    "RIO_DO_CAMPO",
    "RIO_GRANDE",
    "RIO_NEGRINHO",
    "RIO_PARDO",
    "RIO_PARDO_DE_MINAS",
    "RIO_SONO",
    "RIO_URUBU",
    "RIO_VERDE",
    "RONDON_DO_PARA",
    "RONDONOPOLIS",
    "ROSARIO_OESTE",
    "S_G_DA_CACHOEIRA",
    "S_J_DO_RIO_CLARO",
    "SACRAMENTO",
    "SALGUEIRO",
    "SALINAS",
    "SALINOPOLIS",
    "SALTO_DO_CEU",
    "SALVADOR",
    "SALVADOR__RADIO_FAROL",
    "SANTA_CRUZ",
    "SANTA_FE_DO_ARAGUAIA",
    "SANTA_MARIA",
    "SANTA_MARIA_DAS_BARREIRAS",
    "SANTA_MARIA_MADALENA",
    "SANTA_RITA_DE_CASSIA",
    "SANTA_ROSA",
    "SANTA_ROSA_DO_TOCANTINS",
    "SANTA_TERESA",
    "SANTANA_DO_ARAGUAIA",
    "SANTANA_DO_LIVRAMENTO",
    "SANTAREM",
    "SANTIAGO",
    "SANTO_ANTONIO_DO_LESTE",
    "SANTO_AUGUSTO",
    "SAO_BORJA",
    "SAO_CARLOS",
    "SAO_FELIX_DO_ARAGUAIA",
    "SAO_FELIX_DO_XINGU",
    "SAO_GABRIEL",
    "SAO_GABRIEL_DO_OESTE",
    "SAO_GONCALO",
    "SAO_JOAO_DEL_REI",
    "SAO_JOAO_DO_PIAUI",
    "SAO_JOAQUIM",
    "SAO_JOSE_DO_XINGU",
    "SAO_JOSE_DOS_AUSENTES",
    "SAO_LUIS",
    "SAO_LUIS_DO_QUITUNDE",
    "SAO_LUIZ_DO_PARAITINGA",
    "SAO_LUIZ_GONZAGA",
    "SAO_MATEUS",
    "SAO_MATEUS_DO_SUL",
    "SAO_MIGUEL_ARCANJO",
    "SAO_MIGUEL_DO_ARAGUAIA",
    "SAO_MIGUEL_DO_OESTE",
    "SAO_PAULO___INTERLAGOS",
    "SAO_PAULO___MIRANTE",
    "SAO_RAIMUNDO_NONATO",
    "SAO_ROMAO",
    "SAO_SEBASTIAO_DO_PARAISO",
    "SAO_SIMAO",
    "SAO_VICENTE_DO_SUL",
    "SAPEZAL",
    "SAQUAREMA___SAMPAIO_CORREIA",
    "SENHOR_DO_BONFIM",
    "SERAFINA_CORREA",
    "SEROPEDICA_ECOLOGIA_AGRICOLA",
    "SERRA_DOS_AIMORES",
    "SERRA_DOS_CARAJAS",
    "SERRA_NOVA_DOURADA",
    "SERRA_TALHADA",
    "SERRINHA",
    "SETE_LAGOAS",
    "SETE_QUEDAS",
    "SIDROLANDIA",
    "SILVA_JARDIM",
    "SILVANIA",
    "SINOP",
    "SOBRAL",
    "SOLEDADE",
    "SONORA",
    "SOROCABA",
    "SORRISO",
    "SOURE",
    "SURUBIM",
    "SANTA_VITORIA_DO_PALMAR___BARRA_DO_CHUI",
    "TANGARA_DA_SERRA",
    "TAUA",
    "TAUBATE",
    "TEOFILO_OTONI",
    "TERESINA",
    "TERESOPOLIS_PARQUE_NACIONAL",
    "TEUTONIA",
    "TIANGUA",
    "TIMOTEO",
    "TOME_ACU",
    "TORRES",
    "TRAMANDAI",
    "TRES_LAGOAS",
    "TRES_MARIAS",
    "TRES_RIOS",
    "TUCUMA",
    "TUCURUI",
    "TUPA",
    "TUPANCIRETA",
    "TURIACU",
    "UBERABA",
    "UBERLANDIA",
    "UNA",
    "UNAI",
    "URUCARA",
    "URUCUI",
    "URUGUAIANA",
    "URUSSANGA",
    "VACARIA",
    "VALENCA",
    "VALENCA_DO_PIAUI",
    "VALPARAISO",
    "VARGINHA",
    "VENDA_NOVA_DO_IMIGRANTE",
    "VENTANIA",
    "VICOSA",
    "VILA_BELA_DA_SANTISSIMA_TRINDADE",
    "VILA_VELHA",
    "VILHENA",
    "VITORIA",
    "VITORIA_DA_CONQUISTA",
    "XANXERE",
    "XINGUARA",
    "ZE_DOCA",
]

# %%
import os

cidades_rs = [
    "Alegrete",
    "Alegre",
    "Alegrete",
    "Bage",
    "Barra do Rio Grande",
    "Bento Goncalves",
    "Bom Jesus",
    "Cacapava do Sul",
    "Cacequi",
    "Cachoeira do Sul",
    "Camaqua",
    "Cambara do Sul",
    "Campo Bom",
    "Canela",
    "Caxias do Sul",
    "Cruz Alta",
    "Dom Pedrito",
    "Encruzilhada do Sul",
    "Guapore",
    "Ibiruba",
    "Irai",
    "Itaqui",
    "Jaguarao",
    "Lagoa Vermelha",
    "Lajeado",
    "Marcelino Ramos",
    "Morro de Santa Tereza",
    "Novo Hamburgo",
    "Palmeira das Missoes",
    "Panambi",
    "Passo Fundo",
    "Pelotas",
    "Piratini",
    "Porto Alegre",
    "Porto Lucena",
    "Rio Grande",
    "Santa Cruz do Sul",
    "Santa Maria",
    "Santa Rosa",
    "Santa Vitoria do Palmar",
    "Santana da Boa Vista",
    "Santana do Livramento",
    "Santiago",
    "Santo Angelo",
    "Sao Borja",
    "Sao Francisco de Paula",
    "Sao Gabriel",
    "Sao Luiz Gonzaga",
    "Soledade",
    "Tapes",
    "Taquara",
    "Taquari",
    "Teutonia",
    "Torres",
    "Tres de Maio",
    "Tres Passos"
]

cidades_rs = [cidade.upper() for cidade in cidades_rs]
cidades_rs = [cidade.replace(' ', '_') for cidade in cidades_rs]

for cidade in cidades_rs:
    print(f"cidade: {cidade}")

paths_rs = []
counter = 0

for path in lista_total:
    # Extrair o nome da cidade do path
    nome_cidade = lista_total_strings[counter]  # Assumindo que o nome da cidade está na segunda posição após o _
    
    counter += 1
    # Adicionar à lista se houver correspondência
    if nome_cidade in cidades_rs:
        paths_rs.append(nome_cidade)
# Out:
# cidade: ALEGRETE
# cidade: ALEGRE
# cidade: ALEGRETE
# cidade: BAGE
# cidade: BARRA_DO_RIO_GRANDE
# cidade: BENTO_GONCALVES
# cidade: BOM_JESUS
# cidade: CACAPAVA_DO_SUL
# cidade: CACEQUI
# cidade: CACHOEIRA_DO_SUL
# cidade: CAMAQUA
# cidade: CAMBARA_DO_SUL
# cidade: CAMPO_BOM
# cidade: CANELA
# cidade: CAXIAS_DO_SUL
# cidade: CRUZ_ALTA
# cidade: DOM_PEDRITO
# cidade: ENCRUZILHADA_DO_SUL
# cidade: GUAPORE
# cidade: IBIRUBA
# cidade: IRAI
# cidade: ITAQUI
# cidade: JAGUARAO
# cidade: LAGOA_VERMELHA
# cidade: LAJEADO
# cidade: MARCELINO_RAMOS
# cidade: MORRO_DE_SANTA_TEREZA
# cidade: NOVO_HAMBURGO
# cidade: PALMEIRA_DAS_MISSOES
# cidade: PANAMBI
# cidade: PASSO_FUNDO
# cidade: PELOTAS
# cidade: PIRATINI
# cidade: PORTO_ALEGRE
# cidade: PORTO_LUCENA
# cidade: RIO_GRANDE
# cidade: SANTA_CRUZ_DO_SUL
# cidade: SANTA_MARIA
# cidade: SANTA_ROSA
# cidade: SANTA_VITORIA_DO_PALMAR
# cidade: SANTANA_DA_BOA_VISTA
# cidade: SANTANA_DO_LIVRAMENTO
# cidade: SANTIAGO
# cidade: SANTO_ANGELO
# ...

# %%
print(paths_rs)
# Out:
# ['ALEGRE', 'ALEGRETE', 'BAGE', 'BENTO_GONCALVES', 'CACAPAVA_DO_SUL', 'CAMAQUA', 'CAMBARA_DO_SUL', 'CAMPO_BOM', 'CANELA', 'CRUZ_ALTA', 'IBIRUBA', 'JAGUARAO', 'LAGOA_VERMELHA', 'PALMEIRA_DAS_MISSOES', 'PASSO_FUNDO', 'RIO_GRANDE', 'SANTA_MARIA', 'SANTA_ROSA', 'SANTANA_DO_LIVRAMENTO', 'SANTIAGO', 'SAO_BORJA', 'SAO_GABRIEL', 'SAO_LUIZ_GONZAGA', 'SOLEDADE', 'TEUTONIA', 'TORRES']

# %%
paths_cidades_rs = [PATH_ALEGRE, PATH_ALEGRETE, PATH_BAGE, PATH_BENTO_GONCALVES, PATH_CACAPAVA_DO_SUL, PATH_CAMAQUA, PATH_CAMBARA_DO_SUL, PATH_CAMPO_BOM, PATH_CANELA, PATH_CRUZ_ALTA, PATH_IBIRUBA, PATH_JAGUARAO, PATH_LAGOA_VERMELHA, PATH_PALMEIRA_DAS_MISSOES, PATH_PASSO_FUNDO, PATH_RIO_GRANDE, PATH_SANTA_MARIA, PATH_SANTA_ROSA, PATH_SANTANA_DO_LIVRAMENTO, PATH_SANTIAGO, PATH_SAO_BORJA, PATH_SAO_GABRIEL, PATH_SAO_LUIZ_GONZAGA, PATH_SOLEDADE, PATH_TEUTONIA, PATH_TORRES]

# %%
columns_to_use = ['Data Medicao', 'PRECIPITACAO TOTAL, DIARIO (AUT)(mm)', 'PRESSAO ATMOSFERICA MEDIA DIARIA (AUT)(mB)', 'TEMPERATURA MAXIMA, DIARIA (AUT)(°C)','TEMPERATURA MEDIA, DIARIA (AUT)(°C)','TEMPERATURA MINIMA, DIARIA (AUT)(°C)','UMIDADE RELATIVA DO AR, MEDIA DIARIA (AUT)(%)','VENTO, VELOCIDADE MEDIA DIARIA (AUT)(m/s)']

# %%
df = pd.read_csv(PATH_ALEGRETE, parse_dates=["Data Medicao"],sep=';', usecols=columns_to_use)

# %%
df
# Out:
#     Data Medicao PRECIPITACAO TOTAL, DIARIO (AUT)(mm)  \
# 0     2023-01-01                                    0
# 1     2023-01-02                                    4
# 2     2023-01-03                                    0
# 3     2023-01-04                                    0
# 4     2023-01-05                                    0
# ..           ...                                  ...
# 360   2023-12-27                                    0
# 361   2023-12-28                                    0
# 362   2023-12-29                                   44
# 363   2023-12-30                                   ,2
# 364   2023-12-31                                    0
#
#     PRESSAO ATMOSFERICA MEDIA DIARIA (AUT)(mB)  \
# 0                                   994,695833
# 1                                     993,8625
# 2                                   995,066667
# 3                                   995,917391
# 4                                   997,808333
# ...

# %%
coluna_temp_media = df['TEMPERATURA MEDIA, DIARIA (AUT)(°C)']

# %%
coluna_temp_media.at[1]
# Out:
# '25,3875'

# %%
for index, value in enumerate(coluna_temp_media):
    if isinstance(value, str):
        coluna_temp_media.at[index] = float(value.replace(',', '.'))

# %%
coluna_temp_media[0]
# Out:
# float

# %%
media_temp = coluna_temp_media.mean()

# %%
print(media_temp)
# Out:
# 20.281342599439764

# %%
coluna_temp_media_atuali = df[['Data Medicao','TEMPERATURA MEDIA, DIARIA (AUT)(°C)']]

# %%
coluna_temp_media_atuali
# Out:
#     Data Medicao TEMPERATURA MEDIA, DIARIA (AUT)(°C)
# 0     2023-01-01                           28.991667
# 1     2023-01-02                             25.3875
# 2     2023-01-03                                23.5
# 3     2023-01-04                           25.221739
# 4     2023-01-05                           27.691667
# ..           ...                                 ...
# 360   2023-12-27                           21.940909
# 361   2023-12-28                             25.9875
# 362   2023-12-29                           24.186957
# 363   2023-12-30                           21.330435
# 364   2023-12-31                             20.4625
#
# [365 rows x 2 columns]

# %%
janeiro_temp_med = coluna_temp_media_atuali[:31]

# %%
janeiro_temp_med['TEMPERATURA MEDIA, DIARIA (AUT)(°C)'].mean()
# Out:
# 27.03545683870968

# %%
fev_temp_med = coluna_temp_media_atuali[31:62]

# %%
fev_temp_med['TEMPERATURA MEDIA, DIARIA (AUT)(°C)'].mean()
# Out:
# 25.252809965517244
